# %%
import os
import math
import numpy as np
import pickle as pkl
import re

# %%
# TODO: CHECK KL for n_obs=100 gnk
# TODO: double check that stdev / nan/inf handling is okay
with open("../res/gnk/npe_n_obs_100_n_sims_1000_seed_0/kl.txt", 'rb') as f:
    kl = np.loadtxt(f)

# %%
kl
# Out:
# array(6.99894694)

# %% [markdown]
# # gnk

# %%
base_dir = "../res/gnk/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        kl_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "kl.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            kl_value = float(file.read().strip())
                            kl_values.append(kl_value)
                        except ValueError:
                            continue

        # Calculate mean and standard deviation if data is available
        masked_kl_values = np.ma.masked_invalid(kl_values)
        num_valid = np.isfinite(kl_values).sum()
        if num_valid > 0:
            mean_kl = masked_kl_values.mean()
            median_kl = np.ma.median(masked_kl_values)
            std_dev_kl = masked_kl_values.std() if num_valid > 1 else 0
            latex_table += f" & {mean_kl:.2f}/{median_kl:.2f} ({std_dev_kl:.2f}) [{num_valid}]"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 9.48/10.29 (1.61) [5] & 8.48/9.23 (1.57) [5] & 6.44/6.29 (0.85) [5] & 4.48/4.28 (0.60) [5] \\
# \hline
# 500  & 9.64/9.41 (0.92) [21] & 6.78/6.85 (0.74) [21] & 4.89/4.89 (0.67) [21] & 2.90/2.91 (0.45) [21] \\
# \hline
# 1000  & 9.21/8.94 (1.12) [21] & 6.26/6.16 (0.85) [21] & 4.37/4.29 (0.46) [21] & 2.78/2.73 (0.71) [21] \\
# \hline
# 5000  & 8.95/8.68 (1.13) [21] & 5.66/5.61 (0.55) [21] & 3.97/3.93 (0.43) [21] & 2.47/2.36 (0.50) [20] \\
# \hline
# \end{tabular}

# %%
np.ma.masked_invalid(kl_values).sum() / np.isfinite(kl_values).sum()
# Out:
# masked

# %%
np.isfinite(kl_values).sum()
# Out:
# 0

# %%
base_dir = "../res/gnk/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mmd_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "mmd.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            mmd_value = float(file.read().strip())
                            mmd_values.append(mmd_value)
                        except ValueError:
                            continue

        masked_mmd_values = np.ma.masked_invalid(mmd_values)
        num_valid = np.isfinite(mmd_values).sum()
        if num_valid > 0:
            mean_mmd = masked_mmd_values.mean()
            median_mmd = np.ma.median(masked_mmd_values)
            std_dev_mmd = masked_mmd_values.std() if num_valid > 1 else 0
            latex_table += f" & {mean_mmd:.2f}/{median_mmd:.2f} ({std_dev_mmd:.2f}) [{num_valid}]"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 0.62/0.67 (0.15) [21] & 0.57/0.57 (0.16) [21] & 0.52/0.55 (0.15) [21] & 0.44/0.44 (0.17) [21] \\
# \hline
# 500  & 0.87/0.87 (0.05) [21] & 0.74/0.74 (0.06) [21] & 0.55/0.59 (0.11) [21] & 0.25/0.23 (0.10) [21] \\
# \hline
# 1000  & 0.84/0.83 (0.04) [21] & 0.64/0.63 (0.10) [21] & 0.42/0.39 (0.10) [21] & 0.21/0.20 (0.11) [21] \\
# \hline
# 5000  & 0.71/0.71 (0.10) [21] & 0.37/0.36 (0.07) [21] & 0.22/0.20 (0.08) [21] & 0.13/0.10 (0.10) [20] \\
# \hline
# \end{tabular}

# %% [markdown]
# Bias/Coverage - A

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/gnk/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 3.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "estimated_coverage.npy")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[0] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[0] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        # with open(coverage_path, 'r') as file:
                        #     coverage = file.readline().strip()

                        # numbers_str = re.findall(r'\d+\.\d+', coverage)
                        coverage = np.load(coverage_path)

                        # Convert each string number to a float
                        # coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0][0])
                        coverage_90.append(coverage[0][1])
                        coverage_95.append(coverage[0][2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80_std = np.std(coverage_80)
            coverage_80 = np.mean(coverage_80)
            coverage_90_std = np.std(coverage_90)
            coverage_90 = np.mean(coverage_90)
            coverage_95_std = np.std(coverage_95)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} ({coverage_80_std:.2f}) &{coverage_90:.2f} ({coverage_90_std:.2f}) & {coverage_95:.2f} (({coverage_95_std:.2f}) )\\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.53 (0.64) & 0.46  (0.65) & 0.98 (0.06) &1.00 (0.00) & 1.00 ((0.00) )\\
# \hline
# 100 & 460 & 0.18 (0.22) & 0.18  (0.22) & 1.00 (0.00) &1.00 (0.00) & 1.00 ((0.00) )\\
# \hline
# 100 & 1000 & 0.15 (0.18) & 0.15  (0.17) & 0.99 (0.01) &1.00 (0.00) & 1.00 ((0.00) )\\
# \hline
# 100 & 10000 & 0.11 (0.14) & 0.11  (0.14) & 0.82 (0.07) &0.93 (0.03) & 0.98 ((0.01) )\\
# \hline
# 500 & 500 & 0.12 (0.16) & 0.07  (0.11) & 1.00 (0.00) &1.00 (0.00) & 1.00 ((0.00) )\\
# \hline
# 500 & 3107 & 0.06 (0.07) & 0.06  (0.07) & 0.87 (0.09) &0.97 (0.03) & 0.99 ((0.01) )\\
# \hline
# 500 & 11180 & 0.05 (0.05) & 0.05  (0.05) & 0.77 (0.11) &0.89 (0.07) & 0.96 ((0.04) )\\
# \hline
# 500 & 250000 & 0.05 (0.05) & 0.05  (0.05) & 0.77 (0.05) &0.88 (0.03) & 0.94 ((0.03) )\\
# \hline
# 1000 & 1000 & 0.06 (0.07) & 0.04  (0.05) & 0.99 (0.02) &1.00 (0.00) & 1.00 ((0.00) )\\
# \hline
# 1000 & 6907 & 0.03 (0.05) & 0.03  (0.05) & 0.81 (0.14) &0.92 (0.10) & 0.97 ((0.07) )\\
# \hline
# 1000 & 31622 & 0.03 (0.04) & 0.03  (0.04) & 0.78 (0.07) &0.88 (0.06) & 0.94 ((0.03) )\\
# \hline
# 1000 & 1000000 & 0.03 (0.04) & 0.03  (0.04) & 0.77 (0.07) &0.89 (0.04) & 0.94 ((0.02) )\\
# \hline
# 5000 & 5000 & 0.03 (0.03) & 0.02  (0.03) & 0.89 (0.16) &0.96 (0.07) & 0.99 ((0.02) )\\
# \hline
# 5000 & 42585 & 0.01 (0.01) & 0.01  (0.01) & 0.82 (0.08) &0.93 (0.05) & 0.97 ((0.02) )\\
# \hline
# 5000 & 353553 & 0.01 (0.01) & 0.01  (0.01) & 0.77 (0.08) &0.88 (0.05) & 0.94 ((0.03) )\\
# \hline
# 5000 & 25000000 & 0.01 (0.01) & 0.01  (0.01) & 0.80 (0.05) &0.90 (0.04) & 0.94 ((0.03) )\\
# \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# Extra gnk check - narrow prior - Bias/Coverage - A

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/gnk_narrow_prior/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 3.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "estimated_coverage.npy")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[0] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[0] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        # with open(coverage_path, 'r') as file:
                        #     coverage = file.readline().strip()

                        # numbers_str = re.findall(r'\d+\.\d+', coverage)
                        coverage = np.load(coverage_path)

                        # Convert each string number to a float
                        # coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0][0])
                        coverage_90.append(coverage[0][1])
                        coverage_95.append(coverage[0][2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80_std = np.std(coverage_80)
            coverage_80 = np.mean(coverage_80)
            coverage_90_std = np.std(coverage_90)
            coverage_90 = np.mean(coverage_90)
            coverage_95_std = np.std(coverage_95)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} ({coverage_80_std:.2f}) &{coverage_90:.2f} ({coverage_90_std:.2f}) & {coverage_95:.2f} (({coverage_95_std:.2f}) )\\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.21 (0.26) & 0.25  (0.27) & 0.99 (0.01) &1.00 (0.00) & 1.00 ((0.00) )\\
# \hline
# 100 & 460 & 0.16 (0.18) & 0.13  (0.16) & 0.97 (0.04) &1.00 (0.01) & 1.00 ((0.00) )\\
# \hline
# 100 & 1000 & 0.13 (0.14) & 0.11  (0.13) & 0.92 (0.08) &0.98 (0.03) & 0.99 ((0.01) )\\
# \hline
# 100 & 10000 & 0.10 (0.13) & 0.10  (0.13) & 0.75 (0.05) &0.87 (0.04) & 0.94 ((0.03) )\\
# \hline
# 500 & 500 & 0.08 (0.09) & 0.06  (0.07) & 0.99 (0.04) &1.00 (0.01) & 1.00 ((0.00) )\\
# \hline
# 500 & 3107 & 0.05 (0.06) & 0.05  (0.06) & 0.75 (0.08) &0.89 (0.07) & 0.96 ((0.03) )\\
# \hline
# 500 & 11180 & 0.05 (0.06) & 0.05  (0.06) & 0.73 (0.05) &0.85 (0.04) & 0.93 ((0.03) )\\
# \hline
# 500 & 250000 & 0.04 (0.05) & 0.04  (0.05) & 0.77 (0.05) &0.88 (0.05) & 0.94 ((0.03) )\\
# \hline
# 1000 & 1000 & 0.03 (0.04) & 0.03  (0.03) & 0.87 (0.14) &0.95 (0.08) & 0.99 ((0.02) )\\
# \hline
# 1000 & 6907 & 0.03 (0.04) & 0.03  (0.04) & 0.75 (0.10) &0.86 (0.08) & 0.93 ((0.06) )\\
# \hline
# 1000 & 31622 & 0.03 (0.04) & 0.03  (0.04) & 0.74 (0.06) &0.86 (0.05) & 0.93 ((0.03) )\\
# \hline
# 1000 & 1000000 & 0.03 (0.03) & 0.03  (0.03) & 0.81 (0.06) &0.91 (0.03) & 0.95 ((0.02) )\\
# \hline
# 5000 & 5000 & 0.01 (0.01) & 0.01  (0.01) & 0.86 (0.10) &0.95 (0.05) & 0.99 ((0.01) )\\
# \hline
# 5000 & 42585 & 0.01 (0.01) & 0.01  (0.01) & 0.77 (0.04) &0.88 (0.03) & 0.94 ((0.03) )\\
# \hline
# 5000 & 353553 & 0.01 (0.01) & 0.01  (0.01) & 0.78 (0.04) &0.88 (0.03) & 0.94 ((0.03) )\\
# \hline
# 5000 & 25000000 & 0.01 (0.01) & 0.01  (0.01) & 0.80 (0.04) &0.89 (0.03) & 0.95 ((0.02) )\\
# \hline
# \end{tabular}
# \end{table}

# %%
coverage[0][0]
# Out:
# 0.76

# %% [markdown]
# Bias/Coverage - B

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000, 10000]
base_dir = "../res/gnk/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 1.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[1] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[1] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        with open(coverage_path, 'r') as file:
                            coverage = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d+', coverage)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 3.06 (0.79) & 2.76  (0.98) & 0.68 &0.77 & 0.83 \\
# \hline
# 100 & 460 & 2.21 (0.69) & 1.65  (0.81) & 0.73 &0.83 & 0.89 \\
# \hline
# 100 & 1000 & 1.10 (0.48) & 0.55  (0.46) & 0.71 &0.82 & 0.88 \\
# \hline
# 100 & 10000 & 0.26 (0.27) & 0.23  (0.25) & 0.76 &0.87 & 0.92 \\
# \hline
# 500 & 500 & 0.64 (0.68) & 0.39  (0.60) & 0.72 &0.81 & 0.87 \\
# \hline
# 500 & 3107 & - & - & - & - & - \\
# \hline
# 500 & 11180 & - & - & - & - & - \\
# \hline
# 500 & 250000 & 0.11 (0.14) & 0.11  (0.14) & 0.80 &0.90 & 0.95 \\
# \hline
# 1000 & 1000 & 0.18 (0.19) & 0.22  (0.16) & 0.71 &0.82 & 0.88 \\
# \hline
# 1000 & 6907 & - & - & - & - & - \\
# \hline
# 1000 & 31622 & - & - & - & - & - \\
# \hline
# 1000 & 1000000 & 0.10 (0.11) & 0.09  (0.11) & 0.81 &0.91 & 0.95 \\
# \hline
# 5000 & 5000 & 0.15 (0.06) & 0.13  (0.07) & 0.75 &0.86 & 0.91 \\
# \hline
# 5000 & 42585 & - & - & - & - & - \\
# \hline
# 5000 & 353553 & - & - & - & - & - \\
# \hline
# 5000 & 25000000 & 0.03 (0.03) & 0.03  (0.03) & 0.81 &0.90 & 0.95 \\
# \hline
# 10000 & 10000 & 0.09 (0.08) & 0.08  (0.07) & 0.76 &0.87 & 0.93 \\
# \hline
# 10000 & 92103 & - & - & - & - & - \\
# \hline
# 10000 & 1000000 & 0.02 (0.03) & 0.02  (0.03) & 0.82 &0.91 & 0.95 \\
# \hline
# 10000 & 100000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# Bias/Coverage - g

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000, 10000]
base_dir = "../res/gnk/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 2.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[2] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[2] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        with open(coverage_path, 'r') as file:
                            coverage = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d+', coverage)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 2.91 (0.53) & 2.82  (0.85) & 0.68 &0.77 & 0.83 \\
# \hline
# 100 & 460 & 3.23 (0.31) & 3.25  (0.46) & 0.73 &0.83 & 0.88 \\
# \hline
# 100 & 1000 & 3.36 (0.45) & 3.49  (0.66) & 0.71 &0.82 & 0.88 \\
# \hline
# 100 & 10000 & 3.09 (0.48) & 3.04  (0.70) & 0.76 &0.87 & 0.92 \\
# \hline
# 500 & 500 & 3.26 (0.38) & 3.33  (0.60) & 0.72 &0.81 & 0.87 \\
# \hline
# 500 & 3107 & 2.49 (0.37) & 2.16  (0.53) & 0.72 &0.84 & 0.90 \\
# \hline
# 500 & 11180 & 1.42 (0.69) & 1.10  (0.72) & 0.73 &0.85 & 0.91 \\
# \hline
# 500 & 250000 & 0.49 (0.58) & 0.43  (0.53) & 0.80 &0.90 & 0.95 \\
# \hline
# 1000 & 1000 & 2.64 (0.40) & 2.30  (0.66) & 0.71 &0.82 & 0.88 \\
# \hline
# 1000 & 6907 & 1.35 (0.52) & 1.01  (0.50) & 0.75 &0.87 & 0.93 \\
# \hline
# 1000 & 31622 & 0.46 (0.47) & 0.40  (0.45) & 0.78 &0.89 & 0.94 \\
# \hline
# 1000 & 1000000 & 0.23 (0.29) & 0.22  (0.27) & 0.80 &0.91 & 0.95 \\
# \hline
# 5000 & 5000 & 1.39 (0.47) & 1.05  (0.40) & 0.76 &0.86 & 0.92 \\
# \hline
# 5000 & 42585 & 0.22 (0.14) & 0.21  (0.14) & 0.78 &0.89 & 0.94 \\
# \hline
# 5000 & 353553 & 0.14 (0.17) & 0.13  (0.16) & 0.80 &0.90 & 0.95 \\
# \hline
# 5000 & 25000000 & 0.09 (0.11) & 0.09  (0.11) & 0.81 &0.90 & 0.94 \\
# \hline
# 10000 & 10000 & - & - & - & - & - \\
# \hline
# 10000 & 92103 & - & - & - & - & - \\
# \hline
# 10000 & 1000000 & - & - & - & - & - \\
# \hline
# 10000 & 100000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# Bias/Coverage - k

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/gnk/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 0.5

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[3] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[3] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        with open(coverage_path, 'r') as file:
                            coverage = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d+', coverage)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 3.73 (0.47) & 3.51  (0.65) & 0.68 &0.77 & 0.83 \\
# \hline
# 100 & 460 & 3.05 (0.33) & 2.59  (0.39) & 0.73 &0.83 & 0.89 \\
# \hline
# 100 & 1000 & 2.80 (0.32) & 2.31  (0.46) & 0.71 &0.82 & 0.88 \\
# \hline
# 100 & 10000 & 2.16 (0.52) & 1.78  (0.59) & 0.76 &0.87 & 0.92 \\
# \hline
# 500 & 500 & 2.77 (0.37) & 2.42  (0.53) & 0.72 &0.81 & 0.87 \\
# \hline
# 500 & 3107 & - & - & - & - & - \\
# \hline
# 500 & 11180 & - & - & - & - & - \\
# \hline
# 500 & 250000 & 0.15 (0.18) & 0.16  (0.20) & 0.80 &0.90 & 0.95 \\
# \hline
# 1000 & 1000 & 2.61 (0.41) & 2.35  (0.48) & 0.71 &0.82 & 0.88 \\
# \hline
# 1000 & 6907 & - & - & - & - & - \\
# \hline
# 1000 & 31622 & - & - & - & - & - \\
# \hline
# 1000 & 1000000 & 0.20 (0.23) & 0.21  (0.25) & 0.81 &0.91 & 0.95 \\
# \hline
# 5000 & 5000 & 1.16 (0.40) & 0.97  (0.40) & 0.75 &0.86 & 0.91 \\
# \hline
# 5000 & 42585 & - & - & - & - & - \\
# \hline
# 5000 & 353553 & - & - & - & - & - \\
# \hline
# 5000 & 25000000 & 0.06 (0.08) & 0.06  (0.08) & 0.81 &0.90 & 0.95 \\
# \hline
# 10000 & 10000 & 0.56 (0.29) & 0.46  (0.31) & 0.76 &0.87 & 0.93 \\
# \hline
# 10000 & 92103 & - & - & - & - & - \\
# \hline
# 10000 & 1000000 & 0.07 (0.09) & 0.08  (0.09) & 0.82 &0.91 & 0.95 \\
# \hline
# 10000 & 100000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/gnk/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 100.0

latex_table = "\\begin{tabular}{|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "true_in_credible_interval.txt")
                try:
                    with open(coverage_path, 'r') as file:
                        coverage = file.readline().strip()

                        numbers_str = re.findall(r'[0-9]', coverage)

                        # Convert each string number to a float
                        coverage = [int(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if coverage_80:
            coverage_80 = np.sum(coverage_80) / len(coverage_80)
            coverage_90 = np.sum(coverage_90) / len(coverage_90)
            coverage_95 = np.sum(coverage_95) / len(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|}
# \hline
# num obs & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.76 &0.86 & 0.95 \\
# \hline
# 100 & 460 & 0.86 &1.00 & 1.00 \\
# \hline
# 100 & 1000 & 0.81 &0.95 & 1.00 \\
# \hline
# 100 & 10000 & 0.76 &0.95 & 1.00 \\
# \hline
# 500 & 500 & 0.86 &1.00 & 1.00 \\
# \hline
# 500 & 3107 & 0.95 &1.00 & 1.00 \\
# \hline
# 500 & 11180 & 1.00 &1.00 & 1.00 \\
# \hline
# 500 & 250000 & 0.86 &0.90 & 0.90 \\
# \hline
# 1000 & 1000 & 0.86 &0.95 & 1.00 \\
# \hline
# 1000 & 6907 & 0.95 &1.00 & 1.00 \\
# \hline
# 1000 & 31622 & 0.95 &1.00 & 1.00 \\
# \hline
# 1000 & 1000000 & 0.95 &0.95 & 1.00 \\
# \hline
# 5000 & 5000 & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 42585 & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 353553 & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 25000000 & 0.90 &1.00 & 1.00 \\
# \hline
# \end{tabular}
# \end{table}

# %%
# Out:
# array([1, 1, 1])

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/ma6/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
# true_param = 100.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias  & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                bias_path = os.path.join(dir_path, "biases.txt")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(bias_path, 'r') as file:
                        biases = file.read()
                    biases = np.fromstring(biases.strip('[]\n'), sep=' ')
                    bias = np.mean(np.abs(biases[::6]))
                    mean_biases.append(bias)
                    # median_bias = np.median(np.abs(biases[::3]))
                    # median_biases.append(median_bias)
                    # biases = biases.reshape(-1, 1)  # Adjust the shape as needed
                        # posterior_samples = pkl.load(file)
                        # seed_mean_bias = np.mean(posterior_samples, axis=0)[0] - true_param
                        # seed_median_bias = np.median(posterior_samples, axis=0)[0] - true_param
                        # mean_biases.append(seed_mean_bias)
                        # median_biases.append(seed_median_bias)

                    with open(coverage_path, 'r') as file:
                        coverage = file.readline().strip()

                    numbers_str = re.findall(r'\d+\.\d+', coverage)

                    # Convert each string number to a float
                    coverage = [float(num) for num in numbers_str]
                    coverage = np.array(coverage)
                    coverage_80.append(coverage[0])
                    coverage_90.append(coverage[1])
                    coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            # median_bias = np.median(np.abs(median_biases))
            # std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias  & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.53 (0.04) & 0.62 &0.72 & 0.78 \\
# \hline
# 100 & 460 & 0.51 (0.03) & 0.62 &0.71 & 0.78 \\
# \hline
# 100 & 1000 & 0.50 (0.03) & 0.65 &0.74 & 0.82 \\
# \hline
# 100 & 10000 & 0.48 (0.03) & 0.70 &0.83 & 0.89 \\
# \hline
# 500 & 500 & 0.49 (0.03) & 0.61 &0.71 & 0.78 \\
# \hline
# 500 & 3107 & 0.48 (0.03) & 0.65 &0.76 & 0.84 \\
# \hline
# 500 & 11180 & 0.47 (0.03) & 0.69 &0.81 & 0.87 \\
# \hline
# 500 & 250000 & 0.45 (0.03) & 0.78 &0.88 & 0.94 \\
# \hline
# 1000 & 1000 & 0.48 (0.02) & 0.58 &0.70 & 0.77 \\
# \hline
# 1000 & 6907 & 0.47 (0.02) & 0.65 &0.77 & 0.85 \\
# \hline
# 1000 & 31622 & 0.46 (0.02) & 0.69 &0.81 & 0.88 \\
# \hline
# 1000 & 1000000 & 0.45 (0.02) & 0.78 &0.87 & 0.92 \\
# \hline
# 5000 & 5000 & 0.47 (0.03) & 0.64 &0.75 & 0.83 \\
# \hline
# 5000 & 42585 & 0.46 (0.03) & 0.70 &0.81 & 0.89 \\
# \hline
# 5000 & 353553 & 0.44 (0.03) & 0.77 &0.88 & 0.93 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
# base_dir = "../res/ma6/"
# n_obs = 10000
# n_sims = 92103
# highest_kl_seed = None
# highest_kl_value = float('-inf')

# for seed in range(21):
#     dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{seed}/")
#     if os.path.exists(dir_path):
#         full_path = os.path.join(dir_path, "kl.txt")
#         if os.path.isfile(full_path):
#             with open(full_path, 'r') as file:
#                 try:
#                     kl_value = float(file.read().strip())
#                     if kl_value > highest_kl_value:
#                         highest_kl_value = kl_value
#                         highest_kl_seed = seed
#                 except ValueError:
#                     continue

# highest_kl_seed
# Out:
# 0

# %%
base_dir = "../res/ma6/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mmd_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "mmd.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            mmd_value = float(file.read().strip())
                            mmd_values.append(mmd_value)
                        except ValueError:
                            continue

        # Calculate mean and standard deviation if data is available
        if mmd_values:
            mean_mmd = np.nanmean(np.array(mmd_values))
            std_dev_mmd = np.nanstd(np.array(mmd_values)) if len(mmd_values) > 1 else 0
            latex_table += f" & {mean_mmd:.2f} ({std_dev_mmd:.2f})"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 0.36 (0.09) & 0.24 (0.09) & 0.20 (0.09) & 0.14 (0.04) \\
# \hline
# 500  & 0.28 (0.12) & 0.17 (0.13) & 0.15 (0.13) & 0.11 (0.12) \\
# \hline
# 1000  & 0.30 (0.15) & 0.25 (0.23) & 0.20 (0.19) & 0.16 (0.16) \\
# \hline
# 5000  & 0.37 (0.24) & 0.31 (0.25) & 0.22 (0.22) & - \\
# \hline
# \end{tabular}

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/ma6/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 0.5

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[3] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[3] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        with open(coverage_path, 'r') as file:
                            coverage = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d+', coverage)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.57 (0.23) & 0.58  (0.28) & 0.62 &0.72 & 0.78 \\
# \hline
# 100 & 460 & 0.59 (0.32) & 0.61  (0.36) & 0.62 &0.71 & 0.78 \\
# \hline
# 100 & 1000 & 0.60 (0.34) & 0.61  (0.39) & 0.65 &0.74 & 0.82 \\
# \hline
# 100 & 10000 & 0.58 (0.38) & 0.59  (0.42) & 0.70 &0.83 & 0.89 \\
# \hline
# 500 & 500 & 0.57 (0.41) & 0.58  (0.45) & 0.61 &0.71 & 0.78 \\
# \hline
# 500 & 3107 & 0.55 (0.41) & 0.55  (0.42) & 0.65 &0.76 & 0.84 \\
# \hline
# 500 & 11180 & 0.58 (0.40) & 0.58  (0.42) & 0.69 &0.81 & 0.87 \\
# \hline
# 500 & 250000 & 0.57 (0.38) & 0.56  (0.39) & 0.78 &0.88 & 0.94 \\
# \hline
# 1000 & 1000 & 0.54 (0.39) & 0.55  (0.41) & 0.58 &0.70 & 0.77 \\
# \hline
# 1000 & 6907 & 0.55 (0.37) & 0.55  (0.39) & 0.65 &0.77 & 0.85 \\
# \hline
# 1000 & 31622 & 0.57 (0.39) & 0.57  (0.40) & 0.69 &0.81 & 0.88 \\
# \hline
# 1000 & 1000000 & 0.54 (0.35) & 0.53  (0.36) & 0.78 &0.87 & 0.92 \\
# \hline
# 5000 & 5000 & 0.55 (0.39) & 0.55  (0.40) & 0.64 &0.75 & 0.83 \\
# \hline
# 5000 & 42585 & 0.54 (0.39) & 0.54  (0.39) & 0.70 &0.81 & 0.89 \\
# \hline
# 5000 & 353553 & 0.56 (0.40) & 0.55  (0.40) & 0.77 &0.88 & 0.93 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
base_dir = "../res/ma12/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        kl_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "kl.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            kl_value = float(file.read().strip())
                            kl_values.append(kl_value)
                        except ValueError:
                            continue

        # Calculate mean and standard deviation if data is available
        if kl_values:
            mean_kl = np.nanmean(np.array(kl_values))
            median_kl = np.nanmedian(np.array(kl_values))
            std_dev_kl = np.nanstd(np.array(kl_values)) if len(kl_values) > 1 else 0
            latex_table += f" & {mean_kl:.2f}/{median_kl:.2f} ({std_dev_kl:.2f})"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 14.49/13.84 (2.36) & 12.83/12.51 (2.47) & 12.29/11.73 (2.82) & 9.15/8.58 (2.03) \\
# \hline
# 500  & 17.79/19.46 (3.65) & 13.80/14.48 (2.88) & 11.08/11.31 (2.34) & 6.17/6.50 (1.20) \\
# \hline
# 1000  & 19.57/19.99 (4.14) & 13.91/14.55 (2.96) & 9.93/9.78 (1.93) & 7.07/6.76 (1.27) \\
# \hline
# 5000  & 21.98/22.39 (3.21) & 14.90/14.99 (1.97) & 11.07/10.84 (2.29) & - \\
# \hline
# 10000  & - & - & - & - \\
# \hline
# \end{tabular}

# %%
base_dir = "../res/ma12/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mmd_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "mmd.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            mmd_value = float(file.read().strip())
                            mmd_values.append(mmd_value)
                        except ValueError:
                            continue

        # Calculate mean and standard deviation if data is available
        if mmd_values:
            mean_mmd = np.nanmean(np.array(mmd_values))
            std_dev_mmd = np.nanstd(np.array(mmd_values)) if len(mmd_values) > 1 else 0
            latex_table += f" & {mean_mmd:.2f} ({std_dev_mmd:.2f})"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 0.51 (0.06) & 0.45 (0.08) & 0.42 (0.09) & 0.34 (0.09) \\
# \hline
# 500  & 0.54 (0.08) & 0.44 (0.08) & 0.39 (0.08) & 0.23 (0.06) \\
# \hline
# 1000  & 0.55 (0.09) & 0.45 (0.10) & 0.38 (0.13) & 0.35 (0.20) \\
# \hline
# 5000  & 0.57 (0.07) & 0.50 (0.12) & 0.47 (0.11) & - \\
# \hline
# 10000  & - & - & - & - \\
# \hline
# \end{tabular}

# %% [markdown]
# ## MA(2) - Identifiable

# %%
base_dir = "../res/ma2/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        kl_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "kl.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            kl_value = float(file.read().strip())
                            kl_values.append(kl_value)
                        except ValueError:
                            continue

        # Calculate mean and standard deviation if data is available
        masked_kl_values = np.ma.masked_invalid(kl_values)
        num_valid = np.isfinite(kl_values).sum()
        if num_valid > 0:
            mean_kl = masked_kl_values.mean()
            median_kl = np.ma.median(masked_kl_values)
            std_dev_kl = masked_kl_values.std() if num_valid > 1 else 0
            latex_table += f" & {mean_kl:.2f}/{median_kl:.2f} ({std_dev_kl:.2f}) [{num_valid}]"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 1.14/1.03 (0.44) [21] & 0.67/0.70 (0.17) [21] & 0.66/0.61 (0.17) [21] & 0.57/0.51 (0.20) [21] \\
# \hline
# 500  & 0.84/0.85 (0.20) [21] & 0.46/0.44 (0.12) [21] & 0.52/0.50 (0.20) [21] & 0.79/0.79 (0.34) [21] \\
# \hline
# 1000  & 0.63/0.68 (0.22) [21] & 0.48/0.45 (0.19) [21] & 0.76/0.67 (0.45) [20] & 0.95/0.86 (0.57) [20] \\
# \hline
# 5000  & 0.46/0.41 (0.17) [21] & 0.57/0.56 (0.23) [21] & 0.82/0.70 (0.38) [21] & 1.55/1.55 (0.85) [2] \\
# \hline
# \end{tabular}

# %%
base_dir = "../res/ma2/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mmd_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "mmd.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            mmd_value = float(file.read().strip())
                            mmd_values.append(mmd_value)
                        except ValueError:
                            continue

        masked_mmd_values = np.ma.masked_invalid(mmd_values)
        num_valid = np.isfinite(mmd_values).sum()
        if num_valid > 0:
            mean_mmd = masked_mmd_values.mean()
            median_mmd = np.ma.median(masked_mmd_values)
            std_dev_mmd = masked_mmd_values.std() if num_valid > 1 else 0
            latex_table += f" & {mean_mmd:.2f}/{median_mmd:.2f} ({std_dev_mmd:.2f}) [{num_valid}]"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 0.14/0.10 (0.09) [21] & 0.05/0.05 (0.02) [21] & 0.05/0.05 (0.02) [21] & 0.04/0.04 (0.03) [21] \\
# \hline
# 500  & 0.04/0.03 (0.03) [21] & 0.01/0.01 (0.00) [21] & 0.01/0.01 (0.01) [21] & 0.02/0.02 (0.02) [21] \\
# \hline
# 1000  & 0.01/0.01 (0.01) [21] & 0.01/0.01 (0.01) [21] & 0.02/0.01 (0.02) [20] & 0.02/0.01 (0.03) [20] \\
# \hline
# 5000  & 0.00/0.00 (0.00) [21] & 0.01/0.01 (0.01) [21] & 0.01/0.01 (0.01) [21] & 0.03/0.03 (0.02) [2] \\
# \hline
# \end{tabular}

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/ma2/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
# true_param = 100.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias  & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                bias_path = os.path.join(dir_path, "biases.txt")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(bias_path, 'r') as file:
                        biases = file.read()
                    biases = np.fromstring(biases.strip('[]\n'), sep=' ')
                    bias = np.mean(np.abs(biases[::2]))
                    mean_biases.append(bias)
                    # median_bias = np.median(np.abs(biases[::3]))
                    # median_biases.append(median_bias)
                    # biases = biases.reshape(-1, 1)  # Adjust the shape as needed
                        # posterior_samples = pkl.load(file)
                        # seed_mean_bias = np.mean(posterior_samples, axis=0)[0] - true_param
                        # seed_median_bias = np.median(posterior_samples, axis=0)[0] - true_param
                        # mean_biases.append(seed_mean_bias)
                        # median_biases.append(seed_median_bias)

                    with open(coverage_path, 'r') as file:
                        coverage_original = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d?', coverage_original)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            # median_bias = np.median(np.abs(median_biases))
            # std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias  & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.20 (0.11) & 0.73 &0.82 & 0.86 \\
# \hline
# 100 & 460 & 0.12 (0.01) & 0.74 &0.85 & 0.90 \\
# \hline
# 100 & 1000 & 0.12 (0.01) & 0.72 &0.84 & 0.90 \\
# \hline
# 100 & 10000 & 0.11 (0.01) & 0.72 &0.83 & 0.89 \\
# \hline
# 500 & 500 & 0.07 (0.01) & 0.78 &0.87 & 0.90 \\
# \hline
# 500 & 3107 & 0.06 (0.01) & 0.75 &0.87 & 0.90 \\
# \hline
# 500 & 11180 & 0.05 (0.00) & 0.76 &0.84 & 0.90 \\
# \hline
# 500 & 250000 & 0.05 (0.00) & 0.76 &0.87 & 0.90 \\
# \hline
# 1000 & 1000 & 0.04 (0.00) & 0.72 &0.87 & 0.89 \\
# \hline
# 1000 & 6907 & 0.04 (0.00) & 0.74 &0.83 & 0.90 \\
# \hline
# 1000 & 31622 & 0.04 (0.00) & 0.75 &0.84 & 0.90 \\
# \hline
# 1000 & 1000000 & 0.04 (0.00) & 0.76 &0.86 & 0.90 \\
# \hline
# 5000 & 5000 & 0.02 (0.00) & 0.73 &0.85 & 0.90 \\
# \hline
# 5000 & 42585 & 0.02 (0.00) & 0.74 &0.85 & 0.90 \\
# \hline
# 5000 & 353553 & 0.02 (0.00) & 0.73 &0.83 & 0.90 \\
# \hline
# 5000 & 25000000 & 0.02 (0.00) & 0.70 &0.80 & 0.90 \\
# \hline
# \end{tabular}
# \end{table}

# %%
dir_path
# Out:
# '../res/ma2/npe_n_obs_500_n_sims_3107_seed_14/'

# %% [markdown]
# # Stereo

# %% [markdown]
# Rate

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/stereological/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 100.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "estimated_coverage.npy")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[0] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[0] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        coverage = np.load(coverage_path)

                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0][0])
                        coverage_90.append(coverage[0][1])
                        coverage_95.append(coverage[0][2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 2.35 (2.92) & 1.96  (2.30) & 0.98 &1.00 & 1.00 \\
# \hline
# 100 & 460 & 1.41 (1.53) & 1.04  (1.26) & 0.97 &1.00 & 1.00 \\
# \hline
# 100 & 1000 & 0.94 (1.10) & 0.72  (0.95) & 0.87 &0.97 & 1.00 \\
# \hline
# 100 & 10000 & 0.52 (0.64) & 0.51  (0.65) & 0.82 &0.94 & 0.97 \\
# \hline
# 500 & 500 & 1.27 (1.44) & 1.03  (1.25) & 0.96 &1.00 & 1.00 \\
# \hline
# 500 & 3107 & 0.56 (0.68) & 0.52  (0.63) & 0.87 &0.95 & 0.99 \\
# \hline
# 500 & 11180 & 0.38 (0.44) & 0.38  (0.45) & 0.82 &0.92 & 0.97 \\
# \hline
# 500 & 250000 & 0.46 (0.51) & 0.45  (0.51) & 0.81 &0.91 & 0.96 \\
# \hline
# 1000 & 1000 & 0.96 (0.95) & 0.65  (0.74) & 0.92 &1.00 & 1.00 \\
# \hline
# 1000 & 6907 & 0.42 (0.48) & 0.39  (0.46) & 0.86 &0.95 & 0.99 \\
# \hline
# 1000 & 31622 & 0.42 (0.50) & 0.42  (0.50) & 0.80 &0.91 & 0.96 \\
# \hline
# 1000 & 1000000 & 0.39 (0.42) & 0.39  (0.42) & 0.81 &0.90 & 0.96 \\
# \hline
# 5000 & 5000 & 0.28 (0.37) & 0.27  (0.34) & 0.95 &1.00 & 1.00 \\
# \hline
# 5000 & 42585 & 0.15 (0.19) & 0.15  (0.19) & 0.91 &0.98 & 1.00 \\
# \hline
# 5000 & 353553 & 0.14 (0.16) & 0.14  (0.16) & 0.84 &0.94 & 0.97 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/stereological/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 2.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "estimated_coverage.npy")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[1] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[1] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        coverage = np.load(coverage_path)

                        coverage = np.array(coverage)
                        coverage_80.append(coverage[1][0])
                        coverage_90.append(coverage[1][1])
                        coverage_95.append(coverage[1][2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 1.04 (0.43) & 0.71  (0.40) & 1.00 &1.00 & 1.00 \\
# \hline
# 100 & 460 & 0.78 (0.29) & 0.58  (0.31) & 1.00 &1.00 & 1.00 \\
# \hline
# 100 & 1000 & 0.50 (0.22) & 0.35  (0.18) & 1.00 &1.00 & 1.00 \\
# \hline
# 100 & 10000 & 0.10 (0.11) & 0.06  (0.08) & 0.83 &0.94 & 0.99 \\
# \hline
# 500 & 500 & 0.82 (0.36) & 0.60  (0.34) & 1.00 &1.00 & 1.00 \\
# \hline
# 500 & 3107 & 0.41 (0.22) & 0.27  (0.21) & 0.98 &1.00 & 1.00 \\
# \hline
# 500 & 11180 & 0.10 (0.11) & 0.08  (0.09) & 0.84 &0.94 & 0.98 \\
# \hline
# 500 & 250000 & 0.04 (0.05) & 0.04  (0.05) & 0.78 &0.89 & 0.96 \\
# \hline
# 1000 & 1000 & 0.59 (0.19) & 0.40  (0.19) & 1.00 &1.00 & 1.00 \\
# \hline
# 1000 & 6907 & 0.14 (0.16) & 0.08  (0.13) & 0.97 &1.00 & 1.00 \\
# \hline
# 1000 & 31622 & 0.05 (0.05) & 0.05  (0.05) & 0.82 &0.93 & 0.98 \\
# \hline
# 1000 & 1000000 & 0.03 (0.04) & 0.03  (0.04) & 0.78 &0.89 & 0.95 \\
# \hline
# 5000 & 5000 & 0.27 (0.20) & 0.15  (0.17) & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 42585 & 0.02 (0.03) & 0.02  (0.02) & 0.91 &0.98 & 1.00 \\
# \hline
# 5000 & 353553 & 0.01 (0.01) & 0.01  (0.02) & 0.83 &0.92 & 0.97 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/stereological/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = -0.1

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "estimated_coverage.npy")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[2] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[2] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        coverage = np.load(coverage_path)

                        coverage = np.array(coverage)
                        coverage_80.append(coverage[2][0])
                        coverage_90.append(coverage[2][1])
                        coverage_95.append(coverage[2][2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 1.22 (0.28) & 1.21  (0.38) & 0.24 &0.50 & 0.76 \\
# \hline
# 100 & 460 & 1.06 (0.16) & 0.96  (0.27) & 0.76 &0.91 & 1.00 \\
# \hline
# 100 & 1000 & 0.81 (0.14) & 0.47  (0.20) & 1.00 &1.00 & 1.00 \\
# \hline
# 100 & 10000 & 0.07 (0.06) & 0.01  (0.02) & 0.87 &0.96 & 0.99 \\
# \hline
# 500 & 500 & 1.08 (0.16) & 0.96  (0.29) & 0.62 &0.85 & 0.95 \\
# \hline
# 500 & 3107 & 0.48 (0.23) & 0.20  (0.18) & 1.00 &1.00 & 1.00 \\
# \hline
# 500 & 11180 & 0.07 (0.09) & 0.03  (0.04) & 0.90 &0.97 & 0.99 \\
# \hline
# 500 & 250000 & 0.01 (0.01) & 0.01  (0.01) & 0.81 &0.92 & 0.97 \\
# \hline
# 1000 & 1000 & 0.90 (0.16) & 0.62  (0.26) & 1.00 &0.99 & 1.00 \\
# \hline
# 1000 & 6907 & 0.17 (0.16) & 0.05  (0.07) & 1.00 &1.00 & 1.00 \\
# \hline
# 1000 & 31622 & 0.02 (0.02) & 0.01  (0.02) & 0.86 &0.96 & 0.99 \\
# \hline
# 1000 & 1000000 & 0.01 (0.01) & 0.01  (0.01) & 0.79 &0.90 & 0.95 \\
# \hline
# 5000 & 5000 & 0.36 (0.23) & 0.13  (0.15) & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 42585 & 0.02 (0.02) & 0.01  (0.01) & 0.96 &0.99 & 1.00 \\
# \hline
# 5000 & 353553 & 0.01 (0.01) & 0.00  (0.00) & 0.91 &0.97 & 0.99 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/stereological/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = -0.1

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[2] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[2] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        coverage = np.load(coverage_path)

                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0][0])
                        coverage_90.append(coverage[0][1])
                        coverage_95.append(coverage[0][2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)

# %% [markdown]
# "True coverage"

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/stereological/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 100.0

latex_table = "\\begin{tabular}{|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "true_in_credible_interval.txt")
                try:
                    with open(coverage_path, 'r') as file:
                        coverage = file.readline().strip()

                        numbers_str = re.findall(r'[0-9]', coverage)

                        # Convert each string number to a float
                        coverage = [int(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if coverage_80:
            coverage_80 = np.sum(coverage_80) / len(coverage_80)
            coverage_90 = np.sum(coverage_90) / len(coverage_90)
            coverage_95 = np.sum(coverage_95) / len(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|}
# \hline
# num obs & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.81 &1.00 & 1.00 \\
# \hline
# 100 & 460 & 1.00 &1.00 & 1.00 \\
# \hline
# 100 & 1000 & 1.00 &1.00 & 1.00 \\
# \hline
# 100 & 10000 & 1.00 &1.00 & 1.00 \\
# \hline
# 500 & 500 & 1.00 &1.00 & 1.00 \\
# \hline
# 500 & 3107 & 1.00 &1.00 & 1.00 \\
# \hline
# 500 & 11180 & 0.86 &0.95 & 1.00 \\
# \hline
# 500 & 250000 & - & - & - & - & - \\
# \hline
# 1000 & 1000 & 0.95 &1.00 & 1.00 \\
# \hline
# 1000 & 6907 & 1.00 &1.00 & 1.00 \\
# \hline
# 1000 & 31622 & 0.67 &0.90 & 1.00 \\
# \hline
# 1000 & 1000000 & - & - & - & - & - \\
# \hline
# 5000 & 5000 & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 42585 & 0.95 &0.95 & 1.00 \\
# \hline
# 5000 & 353553 & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
coverage_80
# Out:
# []
