# %%
import os
import math
import numpy as np
import pickle as pkl
import re

# %%
# TODO: CHECK KL for n_obs=100 gnk
# TODO: double check that stdev / nan/inf handling is okay
with open("../res/gnk/npe_n_obs_100_n_sims_1000_seed_0/kl.txt", 'rb') as f:
    kl = np.loadtxt(f)

# %%
kl
# Out:
# array(6.99894694)

# %% [markdown]
# # gnk

# %%
base_dir = "../res/gnk/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        kl_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "kl.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            kl_value = float(file.read().strip())
                            kl_values.append(kl_value)
                        except ValueError:
                            continue

        # Calculate mean and standard deviation if data is available
        masked_kl_values = np.ma.masked_invalid(kl_values)
        num_valid = np.isfinite(kl_values).sum()
        if num_valid > 0:
            mean_kl = masked_kl_values.mean()
            median_kl = np.ma.median(masked_kl_values)
            std_dev_kl = masked_kl_values.std() if num_valid > 1 else 0
            latex_table += f" & {mean_kl:.2f}/{median_kl:.2f} ({std_dev_kl:.2f}) [{num_valid}]"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 9.48/10.29 (1.61) [5] & 8.48/9.23 (1.57) [5] & 6.44/6.29 (0.85) [5] & 4.48/4.28 (0.60) [5] \\
# \hline
# 500  & 9.64/9.41 (0.92) [21] & 6.78/6.85 (0.74) [21] & 4.89/4.89 (0.67) [21] & 2.90/2.91 (0.45) [21] \\
# \hline
# 1000  & 9.21/8.94 (1.12) [21] & 6.26/6.16 (0.85) [21] & 4.37/4.29 (0.46) [21] & 2.78/2.73 (0.71) [21] \\
# \hline
# 5000  & 8.95/8.68 (1.13) [21] & 5.66/5.61 (0.55) [21] & 3.97/3.93 (0.43) [21] & 2.47/2.36 (0.50) [20] \\
# \hline
# \end{tabular}

# %%
np.ma.masked_invalid(kl_values).sum() / np.isfinite(kl_values).sum()
# Out:
# masked

# %%
np.isfinite(kl_values).sum()
# Out:
# 0

# %%
base_dir = "../res/gnk/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mmd_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "mmd.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            mmd_value = float(file.read().strip())
                            mmd_values.append(mmd_value)
                        except ValueError:
                            continue

        masked_mmd_values = np.ma.masked_invalid(mmd_values)
        num_valid = np.isfinite(mmd_values).sum()
        if num_valid > 0:
            mean_mmd = masked_mmd_values.mean()
            median_mmd = np.ma.median(masked_mmd_values)
            std_dev_mmd = masked_mmd_values.std() if num_valid > 1 else 0
            latex_table += f" & {mean_mmd:.2f}/{median_mmd:.2f} ({std_dev_mmd:.2f}) [{num_valid}]"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 0.62/0.67 (0.15) [21] & 0.57/0.57 (0.16) [21] & 0.52/0.55 (0.15) [21] & 0.44/0.44 (0.17) [21] \\
# \hline
# 500  & 0.87/0.87 (0.05) [21] & 0.74/0.74 (0.06) [21] & 0.55/0.59 (0.11) [21] & 0.25/0.23 (0.10) [21] \\
# \hline
# 1000  & 0.84/0.83 (0.04) [21] & 0.64/0.63 (0.10) [21] & 0.42/0.39 (0.10) [21] & 0.21/0.20 (0.11) [21] \\
# \hline
# 5000  & 0.71/0.71 (0.10) [21] & 0.37/0.36 (0.07) [21] & 0.22/0.20 (0.08) [21] & 0.13/0.10 (0.10) [20] \\
# \hline
# \end{tabular}

# %% [markdown]
# Bias/Coverage - A

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/gnk/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 3.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[0] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[0] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        with open(coverage_path, 'r') as file:
                            coverage = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d+', coverage)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80_std = np.std(coverage_80)
            coverage_80 = np.mean(coverage_80)
            coverage_90_std = np.std(coverage_90)
            coverage_90 = np.mean(coverage_90)
            coverage_95_std = np.std(coverage_95)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} ({coverage_80_std:.2f}) &{coverage_90:.2f} ({coverage_90_std:.2f}) & {coverage_95:.2f} (({coverage_95_std:.2f}) )\\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.53 (0.64) & 0.46  (0.65) & 0.68 (0.09) &0.77 (0.07) & 0.83 ((0.06) )\\
# \hline
# 100 & 460 & 0.18 (0.22) & 0.18  (0.22) & 0.73 (0.06) &0.83 (0.05) & 0.88 ((0.04) )\\
# \hline
# 100 & 1000 & 0.15 (0.18) & 0.15  (0.17) & 0.71 (0.05) &0.82 (0.04) & 0.88 ((0.03) )\\
# \hline
# 100 & 10000 & 0.11 (0.14) & 0.11  (0.14) & 0.76 (0.05) &0.87 (0.03) & 0.92 ((0.03) )\\
# \hline
# 500 & 500 & 0.12 (0.16) & 0.07  (0.11) & 0.72 (0.05) &0.81 (0.04) & 0.87 ((0.03) )\\
# \hline
# 500 & 3107 & 0.06 (0.07) & 0.06  (0.07) & 0.72 (0.04) &0.84 (0.03) & 0.90 ((0.03) )\\
# \hline
# 500 & 11180 & 0.05 (0.05) & 0.05  (0.05) & 0.73 (0.04) &0.85 (0.03) & 0.91 ((0.03) )\\
# \hline
# 500 & 250000 & 0.05 (0.05) & 0.05  (0.05) & 0.80 (0.04) &0.90 (0.03) & 0.95 ((0.02) )\\
# \hline
# 1000 & 1000 & 0.06 (0.07) & 0.04  (0.05) & 0.71 (0.04) &0.82 (0.03) & 0.88 ((0.03) )\\
# \hline
# 1000 & 6907 & 0.03 (0.05) & 0.03  (0.05) & 0.75 (0.04) &0.87 (0.04) & 0.93 ((0.03) )\\
# \hline
# 1000 & 31622 & 0.03 (0.04) & 0.03  (0.04) & 0.78 (0.04) &0.89 (0.03) & 0.94 ((0.03) )\\
# \hline
# 1000 & 1000000 & 0.03 (0.04) & 0.03  (0.04) & 0.80 (0.04) &0.91 (0.03) & 0.95 ((0.02) )\\
# \hline
# 5000 & 5000 & 0.03 (0.03) & 0.02  (0.03) & 0.76 (0.04) &0.86 (0.03) & 0.92 ((0.03) )\\
# \hline
# 5000 & 42585 & 0.01 (0.01) & 0.01  (0.01) & 0.78 (0.03) &0.89 (0.03) & 0.94 ((0.02) )\\
# \hline
# 5000 & 353553 & 0.01 (0.01) & 0.01  (0.01) & 0.80 (0.05) &0.90 (0.03) & 0.95 ((0.02) )\\
# \hline
# 5000 & 25000000 & 0.01 (0.01) & 0.01  (0.01) & 0.81 (0.04) &0.90 (0.02) & 0.94 ((0.02) )\\
# \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# Bias/Coverage - B

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000, 10000]
base_dir = "../res/gnk/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 1.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[1] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[1] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        with open(coverage_path, 'r') as file:
                            coverage = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d+', coverage)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 3.06 (0.79) & 2.76  (0.98) & 0.68 &0.77 & 0.83 \\
# \hline
# 100 & 460 & 2.21 (0.69) & 1.65  (0.81) & 0.73 &0.83 & 0.89 \\
# \hline
# 100 & 1000 & 1.10 (0.48) & 0.55  (0.46) & 0.71 &0.82 & 0.88 \\
# \hline
# 100 & 10000 & 0.26 (0.27) & 0.23  (0.25) & 0.76 &0.87 & 0.92 \\
# \hline
# 500 & 500 & 0.64 (0.68) & 0.39  (0.60) & 0.72 &0.81 & 0.87 \\
# \hline
# 500 & 3107 & - & - & - & - & - \\
# \hline
# 500 & 11180 & - & - & - & - & - \\
# \hline
# 500 & 250000 & 0.11 (0.14) & 0.11  (0.14) & 0.80 &0.90 & 0.95 \\
# \hline
# 1000 & 1000 & 0.18 (0.19) & 0.22  (0.16) & 0.71 &0.82 & 0.88 \\
# \hline
# 1000 & 6907 & - & - & - & - & - \\
# \hline
# 1000 & 31622 & - & - & - & - & - \\
# \hline
# 1000 & 1000000 & 0.10 (0.11) & 0.09  (0.11) & 0.81 &0.91 & 0.95 \\
# \hline
# 5000 & 5000 & 0.15 (0.06) & 0.13  (0.07) & 0.75 &0.86 & 0.91 \\
# \hline
# 5000 & 42585 & - & - & - & - & - \\
# \hline
# 5000 & 353553 & - & - & - & - & - \\
# \hline
# 5000 & 25000000 & 0.03 (0.03) & 0.03  (0.03) & 0.81 &0.90 & 0.95 \\
# \hline
# 10000 & 10000 & 0.09 (0.08) & 0.08  (0.07) & 0.76 &0.87 & 0.93 \\
# \hline
# 10000 & 92103 & - & - & - & - & - \\
# \hline
# 10000 & 1000000 & 0.02 (0.03) & 0.02  (0.03) & 0.82 &0.91 & 0.95 \\
# \hline
# 10000 & 100000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# Bias/Coverage - g

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000, 10000]
base_dir = "../res/gnk/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 2.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[2] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[2] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        with open(coverage_path, 'r') as file:
                            coverage = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d+', coverage)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 2.91 (0.53) & 2.82  (0.85) & 0.68 &0.77 & 0.83 \\
# \hline
# 100 & 460 & 3.23 (0.31) & 3.25  (0.46) & 0.73 &0.83 & 0.88 \\
# \hline
# 100 & 1000 & 3.36 (0.45) & 3.49  (0.66) & 0.71 &0.82 & 0.88 \\
# \hline
# 100 & 10000 & 3.09 (0.48) & 3.04  (0.70) & 0.76 &0.87 & 0.92 \\
# \hline
# 500 & 500 & 3.26 (0.38) & 3.33  (0.60) & 0.72 &0.81 & 0.87 \\
# \hline
# 500 & 3107 & 2.49 (0.37) & 2.16  (0.53) & 0.72 &0.84 & 0.90 \\
# \hline
# 500 & 11180 & 1.42 (0.69) & 1.10  (0.72) & 0.73 &0.85 & 0.91 \\
# \hline
# 500 & 250000 & 0.49 (0.58) & 0.43  (0.53) & 0.80 &0.90 & 0.95 \\
# \hline
# 1000 & 1000 & 2.64 (0.40) & 2.30  (0.66) & 0.71 &0.82 & 0.88 \\
# \hline
# 1000 & 6907 & 1.35 (0.52) & 1.01  (0.50) & 0.75 &0.87 & 0.93 \\
# \hline
# 1000 & 31622 & 0.46 (0.47) & 0.40  (0.45) & 0.78 &0.89 & 0.94 \\
# \hline
# 1000 & 1000000 & 0.23 (0.29) & 0.22  (0.27) & 0.80 &0.91 & 0.95 \\
# \hline
# 5000 & 5000 & 1.39 (0.47) & 1.05  (0.40) & 0.76 &0.86 & 0.92 \\
# \hline
# 5000 & 42585 & 0.22 (0.14) & 0.21  (0.14) & 0.78 &0.89 & 0.94 \\
# \hline
# 5000 & 353553 & 0.14 (0.17) & 0.13  (0.16) & 0.80 &0.90 & 0.95 \\
# \hline
# 5000 & 25000000 & 0.09 (0.11) & 0.09  (0.11) & 0.81 &0.90 & 0.94 \\
# \hline
# 10000 & 10000 & - & - & - & - & - \\
# \hline
# 10000 & 92103 & - & - & - & - & - \\
# \hline
# 10000 & 1000000 & - & - & - & - & - \\
# \hline
# 10000 & 100000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# Bias/Coverage - k

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/gnk/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 0.5

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[3] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[3] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        with open(coverage_path, 'r') as file:
                            coverage = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d+', coverage)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 3.73 (0.47) & 3.51  (0.65) & 0.68 &0.77 & 0.83 \\
# \hline
# 100 & 460 & 3.05 (0.33) & 2.59  (0.39) & 0.73 &0.83 & 0.89 \\
# \hline
# 100 & 1000 & 2.80 (0.32) & 2.31  (0.46) & 0.71 &0.82 & 0.88 \\
# \hline
# 100 & 10000 & 2.16 (0.52) & 1.78  (0.59) & 0.76 &0.87 & 0.92 \\
# \hline
# 500 & 500 & 2.77 (0.37) & 2.42  (0.53) & 0.72 &0.81 & 0.87 \\
# \hline
# 500 & 3107 & - & - & - & - & - \\
# \hline
# 500 & 11180 & - & - & - & - & - \\
# \hline
# 500 & 250000 & 0.15 (0.18) & 0.16  (0.20) & 0.80 &0.90 & 0.95 \\
# \hline
# 1000 & 1000 & 2.61 (0.41) & 2.35  (0.48) & 0.71 &0.82 & 0.88 \\
# \hline
# 1000 & 6907 & - & - & - & - & - \\
# \hline
# 1000 & 31622 & - & - & - & - & - \\
# \hline
# 1000 & 1000000 & 0.20 (0.23) & 0.21  (0.25) & 0.81 &0.91 & 0.95 \\
# \hline
# 5000 & 5000 & 1.16 (0.40) & 0.97  (0.40) & 0.75 &0.86 & 0.91 \\
# \hline
# 5000 & 42585 & - & - & - & - & - \\
# \hline
# 5000 & 353553 & - & - & - & - & - \\
# \hline
# 5000 & 25000000 & 0.06 (0.08) & 0.06  (0.08) & 0.81 &0.90 & 0.95 \\
# \hline
# 10000 & 10000 & 0.56 (0.29) & 0.46  (0.31) & 0.76 &0.87 & 0.93 \\
# \hline
# 10000 & 92103 & - & - & - & - & - \\
# \hline
# 10000 & 1000000 & 0.07 (0.09) & 0.08  (0.09) & 0.82 &0.91 & 0.95 \\
# \hline
# 10000 & 100000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/gnk/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 100.0

latex_table = "\\begin{tabular}{|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "true_in_credible_interval.txt")
                try:
                    with open(coverage_path, 'r') as file:
                        coverage = file.readline().strip()

                        numbers_str = re.findall(r'[0-9]', coverage)

                        # Convert each string number to a float
                        coverage = [int(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if coverage_80:
            coverage_80 = np.sum(coverage_80) / len(coverage_80)
            coverage_90 = np.sum(coverage_90) / len(coverage_90)
            coverage_95 = np.sum(coverage_95) / len(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|}
# \hline
# num obs & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.76 &0.86 & 0.95 \\
# \hline
# 100 & 460 & 0.86 &1.00 & 1.00 \\
# \hline
# 100 & 1000 & 0.81 &0.95 & 1.00 \\
# \hline
# 100 & 10000 & 0.76 &0.95 & 1.00 \\
# \hline
# 500 & 500 & 0.86 &1.00 & 1.00 \\
# \hline
# 500 & 3107 & 0.95 &1.00 & 1.00 \\
# \hline
# 500 & 11180 & 1.00 &1.00 & 1.00 \\
# \hline
# 500 & 250000 & 0.86 &0.90 & 0.90 \\
# \hline
# 1000 & 1000 & 0.86 &0.95 & 1.00 \\
# \hline
# 1000 & 6907 & 0.95 &1.00 & 1.00 \\
# \hline
# 1000 & 31622 & 0.95 &1.00 & 1.00 \\
# \hline
# 1000 & 1000000 & 0.95 &0.95 & 1.00 \\
# \hline
# 5000 & 5000 & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 42585 & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 353553 & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 25000000 & 0.90 &1.00 & 1.00 \\
# \hline
# \end{tabular}
# \end{table}

# %%
# Out:
# array([1, 1, 1])

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/ma6/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
# true_param = 100.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias  & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                bias_path = os.path.join(dir_path, "biases.txt")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(bias_path, 'r') as file:
                        biases = file.read()
                    biases = np.fromstring(biases.strip('[]\n'), sep=' ')
                    bias = np.mean(np.abs(biases[::6]))
                    mean_biases.append(bias)
                    # median_bias = np.median(np.abs(biases[::3]))
                    # median_biases.append(median_bias)
                    # biases = biases.reshape(-1, 1)  # Adjust the shape as needed
                        # posterior_samples = pkl.load(file)
                        # seed_mean_bias = np.mean(posterior_samples, axis=0)[0] - true_param
                        # seed_median_bias = np.median(posterior_samples, axis=0)[0] - true_param
                        # mean_biases.append(seed_mean_bias)
                        # median_biases.append(seed_median_bias)

                    with open(coverage_path, 'r') as file:
                        coverage = file.readline().strip()

                    numbers_str = re.findall(r'\d+\.\d+', coverage)

                    # Convert each string number to a float
                    coverage = [float(num) for num in numbers_str]
                    coverage = np.array(coverage)
                    coverage_80.append(coverage[0])
                    coverage_90.append(coverage[1])
                    coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            # median_bias = np.median(np.abs(median_biases))
            # std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias  & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.53 (0.04) & 0.62 &0.72 & 0.78 \\
# \hline
# 100 & 460 & 0.51 (0.03) & 0.62 &0.71 & 0.78 \\
# \hline
# 100 & 1000 & 0.50 (0.03) & 0.65 &0.74 & 0.82 \\
# \hline
# 100 & 10000 & 0.48 (0.03) & 0.70 &0.83 & 0.89 \\
# \hline
# 500 & 500 & 0.49 (0.03) & 0.61 &0.71 & 0.78 \\
# \hline
# 500 & 3107 & 0.48 (0.03) & 0.65 &0.76 & 0.84 \\
# \hline
# 500 & 11180 & 0.47 (0.03) & 0.69 &0.81 & 0.87 \\
# \hline
# 500 & 250000 & 0.45 (0.03) & 0.78 &0.88 & 0.94 \\
# \hline
# 1000 & 1000 & 0.48 (0.02) & 0.58 &0.70 & 0.77 \\
# \hline
# 1000 & 6907 & 0.47 (0.02) & 0.65 &0.77 & 0.85 \\
# \hline
# 1000 & 31622 & 0.46 (0.02) & 0.69 &0.81 & 0.88 \\
# \hline
# 1000 & 1000000 & 0.45 (0.02) & 0.78 &0.87 & 0.92 \\
# \hline
# 5000 & 5000 & 0.47 (0.03) & 0.64 &0.75 & 0.83 \\
# \hline
# 5000 & 42585 & 0.46 (0.03) & 0.70 &0.81 & 0.89 \\
# \hline
# 5000 & 353553 & 0.44 (0.03) & 0.77 &0.88 & 0.93 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
# base_dir = "../res/ma6/"
# n_obs = 10000
# n_sims = 92103
# highest_kl_seed = None
# highest_kl_value = float('-inf')

# for seed in range(21):
#     dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{seed}/")
#     if os.path.exists(dir_path):
#         full_path = os.path.join(dir_path, "kl.txt")
#         if os.path.isfile(full_path):
#             with open(full_path, 'r') as file:
#                 try:
#                     kl_value = float(file.read().strip())
#                     if kl_value > highest_kl_value:
#                         highest_kl_value = kl_value
#                         highest_kl_seed = seed
#                 except ValueError:
#                     continue

# highest_kl_seed
# Out:
# 0

# %%
base_dir = "../res/ma6/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mmd_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "mmd.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            mmd_value = float(file.read().strip())
                            mmd_values.append(mmd_value)
                        except ValueError:
                            continue

        # Calculate mean and standard deviation if data is available
        if mmd_values:
            mean_mmd = np.nanmean(np.array(mmd_values))
            std_dev_mmd = np.nanstd(np.array(mmd_values)) if len(mmd_values) > 1 else 0
            latex_table += f" & {mean_mmd:.2f} ({std_dev_mmd:.2f})"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 0.36 (0.09) & 0.24 (0.09) & 0.20 (0.09) & 0.14 (0.04) \\
# \hline
# 500  & 0.28 (0.12) & 0.17 (0.13) & 0.15 (0.13) & 0.11 (0.12) \\
# \hline
# 1000  & 0.30 (0.15) & 0.25 (0.23) & 0.20 (0.19) & 0.16 (0.16) \\
# \hline
# 5000  & 0.37 (0.24) & 0.31 (0.25) & 0.22 (0.22) & - \\
# \hline
# \end{tabular}

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/ma6/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 0.5

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[3] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[3] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                        with open(coverage_path, 'r') as file:
                            coverage = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d+', coverage)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.57 (0.23) & 0.58  (0.28) & 0.62 &0.72 & 0.78 \\
# \hline
# 100 & 460 & 0.59 (0.32) & 0.61  (0.36) & 0.62 &0.71 & 0.78 \\
# \hline
# 100 & 1000 & 0.60 (0.34) & 0.61  (0.39) & 0.65 &0.74 & 0.82 \\
# \hline
# 100 & 10000 & 0.58 (0.38) & 0.59  (0.42) & 0.70 &0.83 & 0.89 \\
# \hline
# 500 & 500 & 0.57 (0.41) & 0.58  (0.45) & 0.61 &0.71 & 0.78 \\
# \hline
# 500 & 3107 & 0.55 (0.41) & 0.55  (0.42) & 0.65 &0.76 & 0.84 \\
# \hline
# 500 & 11180 & 0.58 (0.40) & 0.58  (0.42) & 0.69 &0.81 & 0.87 \\
# \hline
# 500 & 250000 & 0.57 (0.38) & 0.56  (0.39) & 0.78 &0.88 & 0.94 \\
# \hline
# 1000 & 1000 & 0.54 (0.39) & 0.55  (0.41) & 0.58 &0.70 & 0.77 \\
# \hline
# 1000 & 6907 & 0.55 (0.37) & 0.55  (0.39) & 0.65 &0.77 & 0.85 \\
# \hline
# 1000 & 31622 & 0.57 (0.39) & 0.57  (0.40) & 0.69 &0.81 & 0.88 \\
# \hline
# 1000 & 1000000 & 0.54 (0.35) & 0.53  (0.36) & 0.78 &0.87 & 0.92 \\
# \hline
# 5000 & 5000 & 0.55 (0.39) & 0.55  (0.40) & 0.64 &0.75 & 0.83 \\
# \hline
# 5000 & 42585 & 0.54 (0.39) & 0.54  (0.39) & 0.70 &0.81 & 0.89 \\
# \hline
# 5000 & 353553 & 0.56 (0.40) & 0.55  (0.40) & 0.77 &0.88 & 0.93 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
base_dir = "../res/ma12/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        kl_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "kl.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            kl_value = float(file.read().strip())
                            kl_values.append(kl_value)
                        except ValueError:
                            continue

        # Calculate mean and standard deviation if data is available
        if kl_values:
            mean_kl = np.nanmean(np.array(kl_values))
            median_kl = np.nanmedian(np.array(kl_values))
            std_dev_kl = np.nanstd(np.array(kl_values)) if len(kl_values) > 1 else 0
            latex_table += f" & {mean_kl:.2f}/{median_kl:.2f} ({std_dev_kl:.2f})"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 14.49/13.84 (2.36) & 12.83/12.51 (2.47) & 12.29/11.73 (2.82) & 9.15/8.58 (2.03) \\
# \hline
# 500  & 17.79/19.46 (3.65) & 13.80/14.48 (2.88) & 11.08/11.31 (2.34) & 6.17/6.50 (1.20) \\
# \hline
# 1000  & 19.57/19.99 (4.14) & 13.91/14.55 (2.96) & 9.93/9.78 (1.93) & 7.07/6.76 (1.27) \\
# \hline
# 5000  & 21.98/22.39 (3.21) & 14.90/14.99 (1.97) & 11.07/10.84 (2.29) & - \\
# \hline
# 10000  & - & - & - & - \\
# \hline
# \end{tabular}

# %%
base_dir = "../res/ma12/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mmd_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "mmd.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            mmd_value = float(file.read().strip())
                            mmd_values.append(mmd_value)
                        except ValueError:
                            continue

        # Calculate mean and standard deviation if data is available
        if mmd_values:
            mean_mmd = np.nanmean(np.array(mmd_values))
            std_dev_mmd = np.nanstd(np.array(mmd_values)) if len(mmd_values) > 1 else 0
            latex_table += f" & {mean_mmd:.2f} ({std_dev_mmd:.2f})"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 0.51 (0.06) & 0.45 (0.08) & 0.42 (0.09) & 0.34 (0.09) \\
# \hline
# 500  & 0.54 (0.08) & 0.44 (0.08) & 0.39 (0.08) & 0.23 (0.06) \\
# \hline
# 1000  & 0.55 (0.09) & 0.45 (0.10) & 0.38 (0.13) & 0.35 (0.20) \\
# \hline
# 5000  & 0.57 (0.07) & 0.50 (0.12) & 0.47 (0.11) & - \\
# \hline
# 10000  & - & - & - & - \\
# \hline
# \end{tabular}

# %% [markdown]
# ## MA(2) - Identifiable

# %%
base_dir = "../res/ma2/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        kl_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "kl.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            kl_value = float(file.read().strip())
                            kl_values.append(kl_value)
                        except ValueError:
                            continue

        # Calculate mean and standard deviation if data is available
        masked_kl_values = np.ma.masked_invalid(kl_values)
        num_valid = np.isfinite(kl_values).sum()
        if num_valid > 0:
            mean_kl = masked_kl_values.mean()
            median_kl = np.ma.median(masked_kl_values)
            std_dev_kl = masked_kl_values.std() if num_valid > 1 else 0
            latex_table += f" & {mean_kl:.2f}/{median_kl:.2f} ({std_dev_kl:.2f}) [{num_valid}]"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 1.14/1.03 (0.44) [21] & 0.67/0.70 (0.17) [21] & 0.66/0.61 (0.17) [21] & 0.57/0.51 (0.20) [21] \\
# \hline
# 500  & 0.84/0.85 (0.20) [21] & 0.46/0.44 (0.12) [21] & 0.52/0.50 (0.20) [21] & 0.79/0.79 (0.34) [21] \\
# \hline
# 1000  & 0.63/0.68 (0.22) [21] & 0.48/0.45 (0.19) [21] & 0.76/0.67 (0.45) [20] & 0.95/0.86 (0.57) [20] \\
# \hline
# 5000  & 0.46/0.41 (0.17) [21] & 0.57/0.56 (0.23) [21] & 0.82/0.70 (0.38) [21] & 1.55/1.55 (0.85) [2] \\
# \hline
# \end{tabular}

# %%
base_dir = "../res/ma2/"

observations = [100, 500, 1000, 5000]

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21

# LaTeX table header
latex_table = "\\begin{tabular}{|c|c|c|c|c|}\n\\hline\n"
latex_table += "n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\\\ \n\\hline\n"

# Process each observation level
for n_obs in observations:
    latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mmd_values = []
        # Directory for this configuration
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "mmd.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            mmd_value = float(file.read().strip())
                            mmd_values.append(mmd_value)
                        except ValueError:
                            continue

        masked_mmd_values = np.ma.masked_invalid(mmd_values)
        num_valid = np.isfinite(mmd_values).sum()
        if num_valid > 0:
            mean_mmd = masked_mmd_values.mean()
            median_mmd = np.ma.median(masked_mmd_values)
            std_dev_mmd = masked_mmd_values.std() if num_valid > 1 else 0
            latex_table += f" & {mean_mmd:.2f}/{median_mmd:.2f} ({std_dev_mmd:.2f}) [{num_valid}]"
        else:
            latex_table += " & -"
    latex_table += " \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# n (num obs) & N=n & N=nlog(n) & N=n^(3/2) & N=n^2 \\
# \hline
# 100  & 0.14/0.10 (0.09) [21] & 0.05/0.05 (0.02) [21] & 0.05/0.05 (0.02) [21] & 0.04/0.04 (0.03) [21] \\
# \hline
# 500  & 0.04/0.03 (0.03) [21] & 0.01/0.01 (0.00) [21] & 0.01/0.01 (0.01) [21] & 0.02/0.02 (0.02) [21] \\
# \hline
# 1000  & 0.01/0.01 (0.01) [21] & 0.01/0.01 (0.01) [21] & 0.02/0.01 (0.02) [20] & 0.02/0.01 (0.03) [20] \\
# \hline
# 5000  & 0.00/0.00 (0.00) [21] & 0.01/0.01 (0.01) [21] & 0.01/0.01 (0.01) [21] & 0.03/0.03 (0.02) [2] \\
# \hline
# \end{tabular}

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/ma2/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
# true_param = 100.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias  & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                bias_path = os.path.join(dir_path, "biases.txt")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(bias_path, 'r') as file:
                        biases = file.read()
                    biases = np.fromstring(biases.strip('[]\n'), sep=' ')
                    bias = np.mean(np.abs(biases[::2]))
                    mean_biases.append(bias)
                    # median_bias = np.median(np.abs(biases[::3]))
                    # median_biases.append(median_bias)
                    # biases = biases.reshape(-1, 1)  # Adjust the shape as needed
                        # posterior_samples = pkl.load(file)
                        # seed_mean_bias = np.mean(posterior_samples, axis=0)[0] - true_param
                        # seed_median_bias = np.median(posterior_samples, axis=0)[0] - true_param
                        # mean_biases.append(seed_mean_bias)
                        # median_biases.append(seed_median_bias)

                    with open(coverage_path, 'r') as file:
                        coverage_original = file.readline().strip()

                        numbers_str = re.findall(r'\d+\.\d?', coverage_original)

                        # Convert each string number to a float
                        coverage = [float(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            # median_bias = np.median(np.abs(median_biases))
            # std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias  & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.20 (0.11) & 0.73 &0.82 & 0.86 \\
# \hline
# 100 & 460 & 0.12 (0.01) & 0.74 &0.85 & 0.90 \\
# \hline
# 100 & 1000 & 0.12 (0.01) & 0.72 &0.84 & 0.90 \\
# \hline
# 100 & 10000 & 0.11 (0.01) & 0.72 &0.83 & 0.89 \\
# \hline
# 500 & 500 & 0.07 (0.01) & 0.78 &0.87 & 0.90 \\
# \hline
# 500 & 3107 & 0.06 (0.01) & 0.75 &0.87 & 0.90 \\
# \hline
# 500 & 11180 & 0.05 (0.00) & 0.76 &0.84 & 0.90 \\
# \hline
# 500 & 250000 & 0.05 (0.00) & 0.76 &0.87 & 0.90 \\
# \hline
# 1000 & 1000 & 0.04 (0.00) & 0.72 &0.87 & 0.89 \\
# \hline
# 1000 & 6907 & 0.04 (0.00) & 0.74 &0.83 & 0.90 \\
# \hline
# 1000 & 31622 & 0.04 (0.00) & 0.75 &0.84 & 0.90 \\
# \hline
# 1000 & 1000000 & 0.04 (0.00) & 0.76 &0.86 & 0.90 \\
# \hline
# 5000 & 5000 & 0.02 (0.00) & 0.73 &0.85 & 0.90 \\
# \hline
# 5000 & 42585 & 0.02 (0.00) & 0.74 &0.85 & 0.90 \\
# \hline
# 5000 & 353553 & 0.02 (0.00) & 0.73 &0.83 & 0.90 \\
# \hline
# 5000 & 25000000 & 0.02 (0.00) & 0.70 &0.80 & 0.90 \\
# \hline
# \end{tabular}
# \end{table}

# %%
dir_path
# Out:
# '../res/ma2/npe_n_obs_500_n_sims_3107_seed_14/'

# %% [markdown]
# # Stereo

# %% [markdown]
# Rate

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/stereological/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 100.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias  & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                bias_path = os.path.join(dir_path, "true_bias.txt")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    # with open(bias_path, 'r') as file:
                    #     biases = file.read()
                    # biases = np.fromstring(biases.strip('[]\n'), sep=' ')
                    # bias = np.mean(np.abs(biases[::3]))
                    with open(bias_path, 'r') as file:
                        bias = file.read()
                        bias = np.fromstring(bias.strip('[]\n'), sep=' ')
                        mean_biases.append(bias[0])
                        median_bias = np.median(bias[0])
                    # median_bias = np.median(np.abs(biases[::3]))
                    # median_biases.append(median_bias)
                    # biases = biases.reshape(-1, 1)  # Adjust the shape as needed
                        # posterior_samples = pkl.load(file)
                        # seed_mean_bias = np.mean(posterior_samples, axis=0)[0] - true_param
                        # seed_median_bias = np.median(posterior_samples, axis=0)[0] - true_param
                        # mean_biases.append(seed_mean_bias)
                        # median_biases.append(seed_median_bias)

                    with open(coverage_path, 'r') as file:
                        coverage = file.readline().strip()

                    numbers_str = re.findall(r'\d+\.\d+', coverage)

                    # Convert each string number to a float
                    coverage = [float(num) for num in numbers_str]
                    coverage = np.array(coverage)
                    coverage_80.append(coverage[0])
                    coverage_90.append(coverage[1])
                    coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            # median_bias = np.median(np.abs(median_biases))
            # std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias  & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 2.52 (3.12) & 0.65 &0.75 & 0.81 \\
# \hline
# 100 & 460 & 1.41 (1.59) & 0.79 &0.86 & 0.90 \\
# \hline
# 100 & 1000 & 0.97 (1.11) & 0.79 &0.87 & 0.92 \\
# \hline
# 100 & 10000 & 0.65 (0.00) & 0.82 &0.89 & 0.98 \\
# \hline
# 500 & 500 & 1.41 (1.57) & 0.75 &0.83 & 0.89 \\
# \hline
# 500 & 3107 & 0.61 (0.73) & 0.52 &0.67 & 0.82 \\
# \hline
# 500 & 11180 & 0.37 (0.47) & 0.41 &0.56 & 0.68 \\
# \hline
# 500 & 250000 & - & - & - & - & - \\
# \hline
# 1000 & 1000 & 0.91 (0.88) & 0.68 &0.81 & 0.89 \\
# \hline
# 1000 & 6907 & 0.47 (0.54) & 0.33 &0.47 & 0.61 \\
# \hline
# 1000 & 31622 & 0.43 (0.53) & 0.25 &0.35 & 0.44 \\
# \hline
# 1000 & 1000000 & - & - & - & - & - \\
# \hline
# 5000 & 5000 & 0.27 (0.37) & 0.26 &0.40 & 0.55 \\
# \hline
# 5000 & 42585 & 0.17 (0.21) & 0.10 &0.16 & 0.23 \\
# \hline
# 5000 & 353553 & 0.12 (0.00) & 0.05 &0.05 & 0.05 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
# Out:
# array([ 1.12106323e+00,  2.61301994e-02, -7.81834126e-03, -1.63955688e-01,
#         9.34685469e-02, -3.30293179e-02, -6.95053101e-01,  5.73167801e-02,
#         1.79456472e-02,  6.13567352e-01,  5.51600456e-02, -1.14019848e-02,
#         8.53477478e-01,  2.47311294e-02, -1.96217299e-02, -6.00143433e-01,
#        -1.03274918e+00,  4.69026566e-02, -7.15103149e-01, -6.82243347e-01,
#         4.56333160e-04, -7.10144043e-01,  2.48073578e-01, -9.63402539e-03,
#         6.91802979e-01, -1.76243782e-01,  5.37152290e-02,  8.90190125e-01,
#        -2.16143608e-01, -8.02719593e-03, -9.17438507e-01,  9.11207199e-02,
#         8.18734169e-02, -3.42575073e-01,  7.12805748e-01, -3.32913399e-02,
#         1.32675171e-01,  7.14118004e-01, -8.51148367e-02, -1.58691406e-01,
#        -2.26786613e-01,  2.86805630e-03, -2.19406128e-01,  2.21233606e-01,
#        -1.72802210e-02, -2.55790710e-01,  1.01822853e-01, -7.01849461e-02,
#        -4.56848145e-02,  8.63626480e-01, -2.10709572e-02, -9.14091110e-01,
#        -4.31565285e-01, -2.66618729e-02, -2.21911621e+00, -2.22496319e+00,
#         4.49985266e-01, -4.21428680e-01, -2.50132561e-01,  3.31255198e-02,
#         2.83523560e-01, -5.32363892e-01,  5.13108373e-02, -1.16847610e+00,
#        -4.56176758e-01, -3.74530554e-02,  3.78662109e-01,  8.55786800e-02,
#        -2.79757380e-02, -3.48449707e-01, -2.92327881e-01,  1.01614036e-02,
#        -1.13467407e+00,  1.83842659e-01,  1.99787617e-02,  2.36811829e+00,
#        -1.94732189e-01,  2.17408538e-02, -1.05955505e+00,  1.18234634e-01,
#        -1.06114149e-03, -3.85284424e-01,  1.51150584e-01, -1.46711111e-01,
#         3.35472107e-01,  4.14909124e-02, -1.06785595e-02, -1.58387756e+00,
#        -4.25359964e-01,  1.99400187e-01, -1.93222046e+00, -6.66140556e-01,
#         4.77900505e-02,  2.28987885e+00, -1.59939766e+00,  3.82671475e-01,
#         1.16877747e+00,  1.92739964e-02,  4.71949577e-03, -6.51649475e-01,
#         9.49710846e-01, -5.04588187e-02,  2.71118164e-01,  3.99847031e-01,
#         5.67033291e-02, -4.47502136e-01, -4.44070816e-01,  4.79182005e-02,
#        -2.12348938e+00, -2.22147942e-01, -2.55254507e-02,  5.67825317e-01,
#        -2.31411934e-01,  1.82076097e-02, -2.01263428e-02,  6.83259964e-01,
#        -1.34486437e-01,  1.12765503e+00, -1.60616636e-03,  7.12478161e-03,
#         1.41833496e+00, -3.10029030e-01,  7.03563690e-02, -3.11065674e-01,
#        -3.34918976e-01, -3.20641994e-02, -9.24789429e-01, -1.25008583e-01,
#        -1.77443027e-03, -3.28659058e-01, -1.04469806e-02, -1.55550241e-02,
#        -4.94651794e-01, -2.88434982e-01,  1.51734799e-03,  1.47892761e+00,
#         1.47970200e-01,  6.95893764e-02, -8.06732178e-02,  7.86155701e-01,
#        -2.94269323e-02, -1.26104736e+00, -6.57303810e-01, -1.57747269e-02,
#        -4.55627441e-01, -5.55710793e-02, -1.02894306e-02,  1.39236450e-01,
#        -1.62284994e+00,  6.65123940e-01,  2.63210297e-01,  1.37229824e+00,
#        -2.35052586e-01, -7.99194336e-01, -1.95353985e-01,  7.63294697e-02,
#        -8.22891235e-01,  4.65613365e-01, -4.11684513e-02, -1.56961441e+00,
#        -5.51879406e-01,  2.20183134e-01,  9.83123779e-01, -1.44792080e-01,
#         5.89588881e-02, -1.92671204e+00,  5.63631058e-01, -2.40986645e-02,
#         2.33779907e-01, -9.45223808e-01,  3.71360779e-03,  5.79185486e-01,
#        -1.23307800e+00,  4.62003797e-02,  1.61622620e+00,  1.81639552e-01,
#        -2.89469481e-01, -1.52827454e+00, -3.63694191e-01,  7.76088238e-03,
#        -2.92358398e-02,  4.70762253e-02, -1.90598965e-02, -3.49121094e-01,
#         9.23127532e-02, -2.85175562e-01, -7.45780945e-01, -2.76874006e-03,
#         3.60960960e-02,  2.15171814e+00,  4.61511612e-02, -9.67156887e-03,
#         7.17315674e-01,  4.54454422e-01, -8.70785713e-02,  9.85351562e-01,
#        -8.30562115e-02,  2.38858461e-01,  2.31078339e+00, -4.67446804e-01,
#         2.46192217e-02,  1.27639008e+00, -4.08897400e-01,  2.52392530e-01,
#         6.80862427e-01,  2.27679729e-01,  3.37362289e-04, -5.35827637e-01,
#        -3.30006123e-01,  1.21104240e-01, -5.52520752e-02,  7.66180038e-01,
#        -1.04833841e-02,  4.86282349e-01, -2.36526012e-01,  4.57556248e-02,
#         5.02014160e-03, -1.03953362e+00,  5.76073788e-02,  1.74065399e+00,
#        -3.20142746e-01,  4.99857664e-02, -3.99369812e+00, -2.53330231e-01,
#         1.31790340e-02, -7.45910645e-01, -2.67146826e-01,  1.33135319e-02,
#         1.52165222e+00, -2.85514355e+00,  5.01446009e-01,  4.06494141e-01,
#         1.44644737e-01, -7.17747211e-02,  1.49125671e+00, -4.86750603e-01,
#         3.81691456e-02, -2.47123718e+00,  2.46534348e-01,  4.03138995e-03,
#        -8.54545593e-01, -3.10180187e-01,  8.79685163e-01, -7.40913391e-01,
#         1.02745533e-01, -5.82230091e-03,  8.17947388e-02,  3.54080200e-01,
#         4.35471535e-04,  6.38000488e-01,  3.59503269e-01, -1.90264136e-02,
#         1.52460480e+00, -4.15716171e-01,  6.51216507e-03,  1.46160889e+00,
#         8.99163485e-02, -1.83449745e-01,  1.17773438e+00, -8.94384459e-03,
#         5.41806221e-03, -1.35742188e-01, -5.39671898e-01,  2.47277975e-01,
#        -3.66172791e+00, -7.20908642e-02,  5.55419922e-02,  1.57022858e+00,
#         3.04491520e-02, -1.94479823e-02,  4.61456299e-01,  1.10628414e+00,
#        -1.18363023e-01, -3.70216370e-01, -4.01393175e-02, -1.17985010e-01,
#        -1.52648926e-01,  1.09090805e-01, -4.67646122e-02,  7.53425598e-01,
#         2.80088425e-01, -2.70069838e-02, -1.26712418e+00, -1.16243839e+00,
#         1.32916093e-01,  3.75671387e-02, -1.81545198e-01,  5.00509262e-01,
#        -6.15093231e-01, -1.59841537e-01, -1.00894570e-02, -9.67262268e-01,
#        -3.21315050e-01,  2.99192190e-01, -1.45584106e-01, -1.43463230e+00,
#         4.28397655e-02, -7.04391479e-01, -8.13355923e-01,  5.14521837e-01])

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/stereological/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 2.0

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[1] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[1] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                    with open(coverage_path, 'r') as file:
                        coverage = file.readline().strip()

                    numbers_str = re.findall(r'\d+\.\d+', coverage)

                    # Convert each string number to a float
                    coverage = [float(num) for num in numbers_str]
                    coverage = np.array(coverage)
                    coverage_80.append(coverage[0])
                    coverage_90.append(coverage[1])
                    coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.99 (0.41) & 0.70  (0.41) & 0.65 &0.75 & 0.81 \\
# \hline
# 100 & 460 & 0.81 (0.30) & 0.60  (0.31) & 0.79 &0.86 & 0.90 \\
# \hline
# 100 & 1000 & 0.50 (0.20) & 0.35  (0.17) & 0.79 &0.87 & 0.92 \\
# \hline
# 100 & 10000 & 0.22 (0.00) & 0.17  (0.00) & 0.82 &0.89 & 0.98 \\
# \hline
# 500 & 500 & 0.84 (0.36) & 0.61  (0.34) & 0.75 &0.83 & 0.89 \\
# \hline
# 500 & 3107 & 0.41 (0.23) & 0.28  (0.22) & 0.52 &0.67 & 0.82 \\
# \hline
# 500 & 11180 & 0.10 (0.11) & 0.07  (0.10) & 0.41 &0.56 & 0.68 \\
# \hline
# 500 & 250000 & - & - & - & - & - \\
# \hline
# 1000 & 1000 & 0.58 (0.20) & 0.40  (0.20) & 0.68 &0.81 & 0.89 \\
# \hline
# 1000 & 6907 & 0.15 (0.19) & 0.10  (0.15) & 0.33 &0.47 & 0.61 \\
# \hline
# 1000 & 31622 & 0.05 (0.05) & 0.05  (0.05) & 0.25 &0.35 & 0.44 \\
# \hline
# 1000 & 1000000 & - & - & - & - & - \\
# \hline
# 5000 & 5000 & 0.30 (0.22) & 0.18  (0.18) & 0.26 &0.40 & 0.55 \\
# \hline
# 5000 & 42585 & 0.02 (0.03) & 0.02  (0.02) & 0.10 &0.16 & 0.23 \\
# \hline
# 5000 & 353553 & 0.00 (0.00) & 0.01  (0.00) & 0.05 &0.05 & 0.05 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/stereological/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = -0.1

latex_table = "\\begin{tabular}{|c|c|c|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & num sims & Mean Bias & Median Bias & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        mean_biases = []
        median_biases = []
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                npe_samples_path = os.path.join(dir_path, "posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "coverage.txt")
                try:
                    with open(npe_samples_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[2] - true_param
                        seed_median_bias = np.median(posterior_samples, axis=0)[2] - true_param
                        mean_biases.append(seed_mean_bias)
                        median_biases.append(seed_median_bias)

                    with open(coverage_path, 'r') as file:
                        coverage = file.readline().strip()

                    numbers_str = re.findall(r'\d+\.\d+', coverage)

                    # Convert each string number to a float
                    coverage = [float(num) for num in numbers_str]
                    coverage = np.array(coverage)
                    coverage_80.append(coverage[0])
                    coverage_90.append(coverage[1])
                    coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if mean_biases:
            mean_bias = np.mean(np.abs(mean_biases))
            std_dev_mean_bias = np.std(mean_biases)
            median_bias = np.mean(np.abs(median_biases))
            std_dev_median_bias = np.std(median_biases)
            coverage_80 = np.mean(coverage_80)
            coverage_90 = np.mean(coverage_90)
            coverage_95 = np.mean(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {mean_bias:.2f} ({std_dev_mean_bias:.2f}) & {median_bias:.2f}  ({std_dev_median_bias:.2f}) & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# num obs & num sims & Mean Bias & Median Bias & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 1.22 (0.28) & 1.19  (0.38) & 0.65 &0.75 & 0.81 \\
# \hline
# 100 & 460 & 1.08 (0.16) & 0.98  (0.27) & 0.79 &0.86 & 0.90 \\
# \hline
# 100 & 1000 & 0.82 (0.16) & 0.49  (0.21) & 0.79 &0.87 & 0.92 \\
# \hline
# 100 & 10000 & 0.15 (0.00) & 0.04  (0.00) & 0.82 &0.89 & 0.98 \\
# \hline
# 500 & 500 & 1.11 (0.18) & 1.01  (0.32) & 0.75 &0.83 & 0.89 \\
# \hline
# 500 & 3107 & 0.46 (0.25) & 0.20  (0.21) & 0.52 &0.67 & 0.82 \\
# \hline
# 500 & 11180 & 0.08 (0.10) & 0.02  (0.04) & 0.41 &0.56 & 0.68 \\
# \hline
# 500 & 250000 & - & - & - & - & - \\
# \hline
# 1000 & 1000 & 0.89 (0.16) & 0.62  (0.24) & 0.68 &0.81 & 0.89 \\
# \hline
# 1000 & 6907 & 0.19 (0.19) & 0.06  (0.09) & 0.33 &0.47 & 0.61 \\
# \hline
# 1000 & 31622 & 0.02 (0.02) & 0.01  (0.02) & 0.25 &0.35 & 0.44 \\
# \hline
# 1000 & 1000000 & - & - & - & - & - \\
# \hline
# 5000 & 5000 & 0.38 (0.26) & 0.15  (0.15) & 0.26 &0.40 & 0.55 \\
# \hline
# 5000 & 42585 & 0.02 (0.02) & 0.01  (0.01) & 0.10 &0.16 & 0.23 \\
# \hline
# 5000 & 353553 & 0.00 (0.00) & 0.00  (0.00) & 0.05 &0.05 & 0.05 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %% [markdown]
# "True coverage"

# %%
# bias / coverage table
observations = [100, 500, 1000, 5000]
base_dir = "../res/stereological/"

simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]

num_seeds = 21
true_param = 100.0

latex_table = "\\begin{tabular}{|c|c|c|c|}\n\\hline\n"
latex_table += "num obs & 80\\% & 90\\% & 95\\% \\\\ \n\\hline\n"

for n_obs in observations:
    # latex_table += f"{n_obs} "
    for sim_func in simulation_functions:
        n_sims = sim_func(n_obs)
        coverage_80 = []
        coverage_90 = []
        coverage_95 = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                # true_samples_path = os.path.join(dir_path, "true_posterior_samples.pkl")
                coverage_path = os.path.join(dir_path, "true_in_credible_interval.txt")
                try:
                    with open(coverage_path, 'r') as file:
                        coverage = file.readline().strip()

                        numbers_str = re.findall(r'[0-9]', coverage)

                        # Convert each string number to a float
                        coverage = [int(num) for num in numbers_str]
                        coverage = np.array(coverage)
                        coverage_80.append(coverage[0])
                        coverage_90.append(coverage[1])
                        coverage_95.append(coverage[2])
                except FileNotFoundError:
                    continue

        # Calculate mean bias over all seeds if biases were collected
        if coverage_80:
            coverage_80 = np.sum(coverage_80) / len(coverage_80)
            coverage_90 = np.sum(coverage_90) / len(coverage_90)
            coverage_95 = np.sum(coverage_95) / len(coverage_95)
            latex_table += f"{n_obs} & {n_sims} & {coverage_80:.2f} &{coverage_90:.2f} & {coverage_95:.2f} \\\\ \n\\hline\n"
        else:
            latex_table += f"{n_obs} & {n_sims} & - & - & - & - & - \\\\ \n\\hline\n"

# Close the table
latex_table += "\\end{tabular}\n\\end{table}"

# Print the LaTeX table string
print(latex_table)
# Out:
# \begin{tabular}{|c|c|c|c|}
# \hline
# num obs & 80\% & 90\% & 95\% \\
# \hline
# 100 & 100 & 0.81 &1.00 & 1.00 \\
# \hline
# 100 & 460 & 1.00 &1.00 & 1.00 \\
# \hline
# 100 & 1000 & 1.00 &1.00 & 1.00 \\
# \hline
# 100 & 10000 & 1.00 &1.00 & 1.00 \\
# \hline
# 500 & 500 & 1.00 &1.00 & 1.00 \\
# \hline
# 500 & 3107 & 1.00 &1.00 & 1.00 \\
# \hline
# 500 & 11180 & 0.86 &0.95 & 1.00 \\
# \hline
# 500 & 250000 & - & - & - & - & - \\
# \hline
# 1000 & 1000 & 0.95 &1.00 & 1.00 \\
# \hline
# 1000 & 6907 & 1.00 &1.00 & 1.00 \\
# \hline
# 1000 & 31622 & 0.67 &0.90 & 1.00 \\
# \hline
# 1000 & 1000000 & - & - & - & - & - \\
# \hline
# 5000 & 5000 & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 42585 & 0.95 &0.95 & 1.00 \\
# \hline
# 5000 & 353553 & 1.00 &1.00 & 1.00 \\
# \hline
# 5000 & 25000000 & - & - & - & - & - \\
# \hline
# \end{tabular}
# \end{table}

# %%
coverage_80
# Out:
# []
