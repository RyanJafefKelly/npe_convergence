# %%
import matplotlib.pyplot as plt
import pickle as pkl
from scipy.stats import gaussian_kde
import numpy as np
import math
import os

# %% [markdown]
# ## bias boxplots

# %% [markdown]
# ### A

# %%
n_obs_list = [100, 500, 1000, 5000]
simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

num_seeds = 101
true_param = 3.0

base_dir = "../res/gnk/"

for n_obs in n_obs_list:
    all_mean_biases = []
    labels = []
    for ii, sim_fn in enumerate(simulation_functions):
        n_sims = sim_fn(n_obs)
        mean_biases = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "posterior_samples.pkl")
                try:
                    with open(full_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[0] - true_param
                        mean_biases.append(seed_mean_bias)
                except FileNotFoundError:
                    continue
        all_mean_biases.append(mean_biases)
        labels.append(n_sims_label[ii])

    plt.figure(figsize=(10, 6))
    plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
                boxprops=dict(facecolor='lightblue', color='blue'),
                medianprops=dict(color='red', linewidth=2),
                whiskerprops=dict(color='blue'), capprops=dict(color='blue'))
    # plt.title(f'Boxplot of Mean Biases for $n_{{\text{{obs}}}}={n_obs}$', fontsize=16)
    plt.xlabel('Number of Simulations', fontsize=24)
    plt.ylabel('Mean Bias', fontsize=24)
    plt.axhline(y=0, color='black', linestyle='dashed', linewidth=1.5)
    # plt.legend(fontsize=12)
    plt.tick_params(axis='both', which='major', labelsize=18)
    # plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.savefig(f'plots/gnk_A_bias_boxplot_n_obs_{n_obs}.pdf')
    plt.close()
# Out:
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2836586548.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2836586548.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2836586548.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# ...

# %% [markdown]
# ### B

# %%
n_obs_list = [100, 500, 1000, 5000]
simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

num_seeds = 101
true_param = 1.0

base_dir = "../res/gnk/"

for n_obs in n_obs_list:
    all_mean_biases = []
    labels = []
    for ii, sim_fn in enumerate(simulation_functions):
        n_sims = sim_fn(n_obs)
        mean_biases = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "posterior_samples.pkl")
                try:
                    with open(full_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[1] - true_param
                        mean_biases.append(seed_mean_bias)
                except FileNotFoundError:
                    continue
        all_mean_biases.append(mean_biases)
        labels.append(n_sims_label[ii])

    plt.figure(figsize=(10, 6))
    plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
                boxprops=dict(facecolor='lightblue', color='blue'),
                medianprops=dict(color='red', linewidth=2),
                whiskerprops=dict(color='blue'), capprops=dict(color='blue'))
    # plt.title(f'Boxplot of Mean Biases for $n_{{\text{{obs}}}}={n_obs}$', fontsize=16)
    plt.xlabel('Number of Simulations', fontsize=24)
    plt.ylabel('Mean Bias', fontsize=24)
    plt.axhline(y=0, color='black', linestyle='dashed', linewidth=1.5)
    # plt.legend(fontsize=12)
    plt.tick_params(axis='both', which='major', labelsize=18)
    # plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.savefig(f'plots/gnk_B_bias_boxplot_n_obs_{n_obs}.pdf')
    plt.close()
# Out:
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2326443937.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2326443937.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2326443937.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# ...

# %% [markdown]
# ### g

# %%
n_obs_list = [100, 500, 1000, 5000]
simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

num_seeds = 101
true_param = 2.0

base_dir = "../res/gnk/"

for n_obs in n_obs_list:
    all_mean_biases = []
    labels = []
    for ii, sim_fn in enumerate(simulation_functions):
        n_sims = sim_fn(n_obs)
        mean_biases = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "posterior_samples.pkl")
                try:
                    with open(full_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[2] - true_param
                        mean_biases.append(seed_mean_bias)
                except FileNotFoundError:
                    continue
        all_mean_biases.append(mean_biases)
        labels.append(n_sims_label[ii])

    plt.figure(figsize=(10, 6))
    plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
                boxprops=dict(facecolor='lightblue', color='blue'),
                medianprops=dict(color='red', linewidth=2),
                whiskerprops=dict(color='blue'), capprops=dict(color='blue'))
    # plt.title(f'Boxplot of Mean Biases for $n_{{\text{{obs}}}}={n_obs}$', fontsize=16)
    plt.xlabel('Number of Simulations', fontsize=24)
    plt.ylabel('Mean Bias', fontsize=24)
    plt.axhline(y=0, color='black', linestyle='dashed', linewidth=1.5)
    # plt.legend(fontsize=12)
    plt.tick_params(axis='both', which='major', labelsize=18)
    # plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.savefig(f'plots/gnk_g_bias_boxplot_n_obs_{n_obs}.pdf')
    plt.close()
# Out:
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2241092099.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2241092099.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2241092099.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# ...

# %% [markdown]
# ### k

# %%
n_obs_list = [100, 500, 1000, 5000]
simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

num_seeds = 101
true_param = 0.5

base_dir = "../res/gnk/"

for n_obs in n_obs_list:
    all_mean_biases = []
    labels = []
    for ii, sim_fn in enumerate(simulation_functions):
        n_sims = sim_fn(n_obs)
        mean_biases = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "posterior_samples.pkl")
                try:
                    with open(full_path, 'rb') as file:
                        posterior_samples = pkl.load(file)
                        seed_mean_bias = np.mean(posterior_samples, axis=0)[3] - true_param
                        mean_biases.append(seed_mean_bias)
                except FileNotFoundError:
                    continue
        all_mean_biases.append(mean_biases)
        labels.append(n_sims_label[ii])

    plt.figure(figsize=(10, 6))
    plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
                boxprops=dict(facecolor='lightblue', color='blue'),
                medianprops=dict(color='red', linewidth=2),
                whiskerprops=dict(color='blue'), capprops=dict(color='blue'))
    # plt.title(f'Boxplot of Mean Biases for $n_{{\text{{obs}}}}={n_obs}$', fontsize=16)
    plt.xlabel('Number of Simulations', fontsize=24)
    plt.ylabel('Mean Bias', fontsize=24)
    plt.axhline(y=0, color='black', linestyle='dashed', linewidth=1.5)
    # plt.legend(fontsize=12)
    plt.tick_params(axis='both', which='major', labelsize=18)
    # plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.savefig(f'plots/gnk_k_bias_boxplot_n_obs_{n_obs}.pdf')
    plt.close()
# Out:
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2359675328.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2359675328.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/2359675328.py:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_mean_biases, labels=labels, patch_artist=True,
# ...

# %% [markdown]
# ## posterior plots

# %%
n_sims = ["5000", "42585", "353553", "25000000"]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

# Plotting
plt.figure(figsize=(10, 6))  # Set figure size for better readability
bins = None
plt.xlim([2, 4])
colors = plt.cm.viridis(np.linspace(0, 1, len(n_sims)))  # Use a perceptually uniform colormap

for ii, (n_sim, color) in enumerate(zip(n_sims, colors)):
    file_name = f"../res/gnk/npe_n_obs_5000_n_sims_{str(n_sim)}_seed_0/posterior_samples.pkl"
    with open(file_name, 'rb') as file:
        posterior_samples = pkl.load(file)
        rate_samples = posterior_samples[:, 0]
        kde = gaussian_kde(rate_samples.ravel())
        xs = np.linspace(2, 4, 100)
        plt.plot(xs, kde(xs), label=n_sims_label[ii], color=color, linewidth=2)

# Add vertical line with improved style
plt.axvline(3, color="red", linestyle="--", linewidth=1.5)

# Aesthetics improvements
plt.ylim(0, 15)
plt.xlabel(r'$A$', fontsize=24)
plt.ylabel('Density', fontsize=24)
# plt.title('Posterior Distributions for Different $n_{\text{sim}}$', fontsize=16)
plt.legend(fontsize=18, title="Number of Simulations", title_fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)

# Use a style for better presentation (optional)
plt.style.use('seaborn-v0_8-poster')  # or 'ggplot', 'seaborn-darkgrid', etc.

plt.tight_layout()
plt.savefig("plots/gnk_A_posterior.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 12
#      10 for ii, (n_sim, color) in enumerate(zip(n_sims, colors)):
#      11     file_name = f"../res/gnk/npe_n_obs_5000_n_sims_{str(n_sim)}_seed_0/posterior_samples.pkl"
# ---> 12     with open(file_name, 'rb') as file:
#      13         posterior_samples = pkl.load(file)
#      14         rate_samples = posterior_samples[:, 0]
#
# File ~/python_projects/npe_convergence/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
# ...

# %%
n_sims = ["5000", "42585", "353553", "25000000"]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

# Plotting
plt.figure(figsize=(10, 6))  # Set figure size for better readability
bins = None
plt.xlim([0, 2])
colors = plt.cm.viridis(np.linspace(0, 1, len(n_sims)))  # Use a perceptually uniform colormap

for ii, (n_sim, color) in enumerate(zip(n_sims, colors)):
    file_name = f"../res/gnk/npe_n_obs_5000_n_sims_{str(n_sim)}_seed_0/posterior_samples.pkl"
    with open(file_name, 'rb') as file:
        posterior_samples = pkl.load(file)
        rate_samples = posterior_samples[:, 1]
        kde = gaussian_kde(rate_samples.ravel())
        xs = np.linspace(0, 2, 100)
        plt.plot(xs, kde(xs), label=n_sims_label[ii], color=color, linewidth=2)

# Add vertical line with improved style
plt.axvline(1.0, color="red", linestyle="--", linewidth=1.5)

# Aesthetics improvements
plt.ylim(0, 15)
plt.xlabel(r'$B$', fontsize=24)
plt.ylabel('Density', fontsize=24)
# plt.title('Posterior Distributions for Different $n_{\text{sim}}$', fontsize=16)
plt.legend(fontsize=18, title="Number of Simulations", title_fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)

# Use a style for better presentation (optional)
plt.style.use('seaborn-v0_8-poster')  # or 'ggplot', 'seaborn-darkgrid', etc.

plt.tight_layout()
plt.savefig("plots/gnk_B_posterior.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 12
#      10 for ii, (n_sim, color) in enumerate(zip(n_sims, colors)):
#      11     file_name = f"../res/gnk/npe_n_obs_5000_n_sims_{str(n_sim)}_seed_0/posterior_samples.pkl"
# ---> 12     with open(file_name, 'rb') as file:
#      13         posterior_samples = pkl.load(file)
#      14         rate_samples = posterior_samples[:, 1]
#
# File ~/python_projects/npe_convergence/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
# ...

# %%
n_sims = ["5000", "42585", "353553", "25000000"]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

# Plotting
plt.figure(figsize=(10, 6))  # Set figure size for better readability
bins = None
plt.xlim([0, 5])
colors = plt.cm.viridis(np.linspace(0, 1, len(n_sims)))  # Use a perceptually uniform colormap

for ii, (n_sim, color) in enumerate(zip(n_sims, colors)):
    file_name = f"../res/gnk/npe_n_obs_5000_n_sims_{str(n_sim)}_seed_0/posterior_samples.pkl"
    with open(file_name, 'rb') as file:
        posterior_samples = pkl.load(file)
        rate_samples = posterior_samples[:, 2]
        kde = gaussian_kde(rate_samples.ravel())
        xs = np.linspace(0, 5, 100)
        plt.plot(xs, kde(xs), label=n_sims_label[ii], color=color, linewidth=2)

# Add vertical line with improved style
plt.axvline(2.0, color="red", linestyle="--", linewidth=1.5)

# Aesthetics improvements
plt.ylim(0, 2)
plt.xlabel(r'$g$', fontsize=24)
plt.ylabel('Density', fontsize=24)
# plt.title('Posterior Distributions for Different $n_{\text{sim}}$', fontsize=16)
plt.legend(fontsize=18, title="Number of Simulations", title_fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)

# Use a style for better presentation (optional)
plt.style.use('seaborn-v0_8-poster')  # or 'ggplot', 'seaborn-darkgrid', etc.

plt.tight_layout()
plt.savefig("plots/gnk_g_posterior.pdf")

# %%
n_sims = ["5000", "42585", "353553", "25000000"]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

# Plotting
plt.figure(figsize=(10, 6))  # Set figure size for better readability
bins = None
plt.xlim([0, 2])
colors = plt.cm.viridis(np.linspace(0, 1, len(n_sims)))  # Use a perceptually uniform colormap

for ii, (n_sim, color) in enumerate(zip(n_sims, colors)):
    file_name = f"../res/gnk/npe_n_obs_5000_n_sims_{str(n_sim)}_seed_0/posterior_samples.pkl"
    with open(file_name, 'rb') as file:
        posterior_samples = pkl.load(file)
        rate_samples = posterior_samples[:, 3]
        kde = gaussian_kde(rate_samples.ravel())
        xs = np.linspace(0, 2, 100)
        plt.plot(xs, kde(xs), label=n_sims_label[ii], color=color, linewidth=2)

# Add vertical line with improved style
plt.axvline(0.5, color="red", linestyle="--", linewidth=1.5)

# Aesthetics improvements
plt.ylim(0, 15)
plt.xlabel(r'$k$', fontsize=24)
plt.ylabel('Density', fontsize=24)
# plt.title('Posterior Distributions for Different $n_{\text{sim}}$', fontsize=16)
plt.legend(fontsize=18, title="Number of Simulations", title_fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)

# Use a style for better presentation (optional)
plt.style.use('seaborn-v0_8-poster')  # or 'ggplot', 'seaborn-darkgrid', etc.

plt.tight_layout()
plt.savefig("plots/gnk_B_posterior.pdf")

# %% [markdown]
# ### KL Plots

# %%
n_obs_list = [100, 500, 1000, 5000]
simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

num_seeds = 101

base_dir = "../res/gnk/"

for n_obs in n_obs_list:
    all_kl = []
    labels = []
    for ii, sim_fn in enumerate(simulation_functions):
        n_sims = sim_fn(n_obs)
        kl_values = []
        mean_biases = []
        for i in range(num_seeds):
            dir_path = os.path.join(base_dir, f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}/")
            if os.path.exists(dir_path):
                full_path = os.path.join(dir_path, "kl.txt")
                if os.path.isfile(full_path):
                    with open(full_path, 'r') as file:
                        try:
                            kl_value = float(file.read().strip())
                            if math.isfinite(kl_value):
                                kl_values.append(kl_value)
                        except ValueError:
                            continue
        all_kl.append(kl_values)
        # Calculate mean and standard deviation if data is available
        # masked_kl_values = np.ma.masked_invalid(kl_values)
        # num_valid = np.isfinite(kl_values).sum()
        # if num_valid > 0:
        #     mean_kl = masked_kl_values.mean()
        #     median_kl = np.ma.median(masked_kl_values)
        #     std_dev_kl = masked_kl_values.std() if num_valid > 1 else 0
        # all_mean_biases.append(mean_biases)
        labels.append(n_sims_label[ii])

    plt.figure(figsize=(10, 6))
    plt.boxplot(all_kl, labels=labels, patch_artist=True,
                boxprops=dict(facecolor='lightblue', color='blue'),
                medianprops=dict(color='red', linewidth=2),
                whiskerprops=dict(color='blue'), capprops=dict(color='blue'))
    # plt.title(f'Boxplot of Mean Biases for $n_{{\text{{obs}}}}={n_obs}$', fontsize=16)
    plt.xlabel('Number of Simulations', fontsize=24)
    plt.ylabel('Estimated KL', fontsize=24)
    # plt.axhline(y=0, color='red', linestyle='dashed', linewidth=1.5)
    # plt.legend(fontsize=12)
    plt.tick_params(axis='both', which='major', labelsize=18)
    # plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.savefig(f'plots/gnk_kl_n_obs_{n_obs}.pdf')
    plt.close()

# %%
kl_values

# %% [markdown]
# ## octiles vs duodeciles

# %%
import os
import math
import numpy as np
import matplotlib.pyplot as plt

n_obs_list = [100, 500, 1000, 5000]
simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

num_seeds = 101

base_dir_octiles = "../res/gnk/"
base_dir_duodeciles = "../res/gnk_duodeciles/"

for n_obs in n_obs_list:
    # Lists to store statistics for Octiles
    octile_medians = []
    octile_lower_errors = []
    octile_upper_errors = []
    
    # Lists to store statistics for Duodeciles
    duodecile_medians = []
    duodecile_lower_errors = []
    duodecile_upper_errors = []
    
    for ii, sim_fn in enumerate(simulation_functions):
        n_sims = sim_fn(n_obs)
        kl_values_octile = []
        kl_values_duodecile = []
        
        for i in range(num_seeds):
            # Octiles
            dir_path_octile = os.path.join(
                base_dir_octiles,
                f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}"
            )
            kl_file_octile = os.path.join(dir_path_octile, "kl.txt")
            if os.path.isfile(kl_file_octile):
                with open(kl_file_octile, 'r') as file:
                    try:
                        kl_value = float(file.read().strip())
                        if math.isfinite(kl_value):
                            kl_values_octile.append(kl_value)
                    except ValueError:
                        continue
            # Duodeciles
            dir_path_duodecile = os.path.join(
                base_dir_duodeciles,
                f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}"
            )
            kl_file_duodecile = os.path.join(dir_path_duodecile, "kl.txt")
            if os.path.isfile(kl_file_duodecile):
                with open(kl_file_duodecile, 'r') as file:
                    try:
                        kl_value = float(file.read().strip())
                        if math.isfinite(kl_value):
                            kl_values_duodecile.append(kl_value)
                    except ValueError as e:
                        continue
            else:
                dir_path_duodecile = os.path.join(
                    base_dir_duodeciles,
                    f"npe_n_obs_{n_obs}_n_sims_25000000_seed_{str(i)}"
                )
                print(dir_path_duodecile)
                if os.path.isfile(kl_file_duodecile):
                    with open(kl_file_duodecile, 'r') as file:
                        try:
                            kl_value = float(file.read().strip())
                            if math.isfinite(kl_value):
                                kl_values_duodecile.append(kl_value)
                        except ValueError as e:
                            print(e)
                            continue

        # Calculate statistics for Octiles
        print("kl_values_octile", kl_values_octile)
        if kl_values_octile:
            median_octile = np.median(kl_values_octile)
            lower_octile = np.percentile(kl_values_octile, 5)
            upper_octile = np.percentile(kl_values_octile, 95)
            octile_medians.append(median_octile)
            octile_lower_errors.append(median_octile - lower_octile)
            octile_upper_errors.append(upper_octile - median_octile)
        else:
            octile_medians.append(np.nan)
            octile_lower_errors.append(0)
            octile_upper_errors.append(0)
        
        # Calculate statistics for Duodeciles
        print("kl_values_duodecile", kl_values_duodecile)
        if kl_values_duodecile:
            median_duodecile = np.median(kl_values_duodecile)
            lower_duodecile = np.percentile(kl_values_duodecile, 5)
            upper_duodecile = np.percentile(kl_values_duodecile, 95)
            duodecile_medians.append(median_duodecile)
            duodecile_lower_errors.append(median_duodecile - lower_duodecile)
            duodecile_upper_errors.append(upper_duodecile - median_duodecile)
        else:
            print("No data for Duodeciles")
            duodecile_medians.append(np.nan)
            duodecile_lower_errors.append(0)
            duodecile_upper_errors.append(0)
    
    # Convert labels to x positions
    x_positions = np.arange(len(n_sims_label))
    
    # Offset for side-by-side plotting
    offset = 0.01  # Adjust as needed
    width = 0.05  # Width of the markers

    # Plotting
    plt.figure(figsize=(12, 8))
    
    # Octiles
    plt.errorbar(
        x_positions - offset,
        octile_medians,
        yerr=[octile_lower_errors, octile_upper_errors],
        fmt='-o',
        label='Octiles',
        capsize=5,
        markersize=8,
        linewidth=2
    )
    
    # Duodeciles
    plt.errorbar(
        x_positions + offset,
        duodecile_medians,
        yerr=[duodecile_lower_errors, duodecile_upper_errors],
        fmt='-s',
        linestyle='dashed',
        label='Duodeciles',
        capsize=5,
        markersize=8,
        linewidth=2
    )
    print("yes")
    plt.xticks(x_positions, n_sims_label, fontsize=24)
    plt.xlabel("Number of Simulations", fontsize=24)
    plt.ylabel(r"KL Divergence", fontsize=24)
    # plt.title(f"KL Divergence with Error Bars (n_obs = {n_obs})", fontsize=26)
    plt.legend(fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=24)
    plt.tight_layout()
    plt.savefig(f"plots/gnk_summaries_{str(n_obs)}.pdf")
    plt.clf()
# Out:
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_0
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_1
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_6
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_7
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_8
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_9
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_10
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_11
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_13
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_14
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_15
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_16
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_17
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_19
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_20
# ../res/gnk_duodeciles/npe_n_obs_100_n_sims_25000000_seed_21
# ...

# %% [markdown]
# ## Hexadeciles

# %%
import os
import math
import numpy as np
import matplotlib.pyplot as plt

n_obs_list = [100, 500, 1000, 5000]
simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

num_seeds = 101

base_dir_octiles = "../res/gnk/"
base_dir_hexadeciles = "../res/gnk_hexadeciles/"

for n_obs in n_obs_list:
    # Lists to store statistics for Octiles
    octile_medians = []
    octile_lower_errors = []
    octile_upper_errors = []
    
    # Lists to store statistics for Hexadeciles
    hexadecile_medians = []
    hexadecile_lower_errors = []
    hexadecile_upper_errors = []
    
    for ii, sim_fn in enumerate(simulation_functions):
        n_sims = sim_fn(n_obs)
        kl_values_octile = []
        kl_values_hexadecile = []
        
        for i in range(num_seeds):
            # Octiles
            dir_path_octile = os.path.join(
                base_dir_octiles,
                f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}"
            )
            kl_file_octile = os.path.join(dir_path_octile, "kl.txt")
            if os.path.isfile(kl_file_octile):
                with open(kl_file_octile, 'r') as file:
                    try:
                        kl_value = float(file.read().strip())
                        if math.isfinite(kl_value):
                            kl_values_octile.append(kl_value)
                    except ValueError:
                        continue
            # Hexadeciles
            dir_path_hexadecile = os.path.join(
                base_dir_hexadeciles,
                f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}"
            )
            kl_file_hexadecile = os.path.join(dir_path_hexadecile, "kl.txt")
            if os.path.isfile(kl_file_hexadecile):
                with open(kl_file_hexadecile, 'r') as file:
                    try:
                        kl_value = float(file.read().strip())
                        if math.isfinite(kl_value):
                            kl_values_hexadecile.append(kl_value)
                    except ValueError as e:
                        continue

        # Calculate statistics for Octiles
        if kl_values_octile:
            median_octile = np.median(kl_values_octile)
            lower_octile = np.percentile(kl_values_octile, 5)
            upper_octile = np.percentile(kl_values_octile, 95)
            octile_medians.append(median_octile)
            octile_lower_errors.append(median_octile - lower_octile)
            octile_upper_errors.append(upper_octile - median_octile)
        else:
            octile_medians.append(np.nan)
            octile_lower_errors.append(0)
            octile_upper_errors.append(0)
        
        # Calculate statistics for Hexadeciles
        if kl_values_hexadecile:
            median_hexadecile = np.median(kl_values_hexadecile)
            lower_hexadecile = np.percentile(kl_values_hexadecile, 5)
            upper_hexadecile = np.percentile(kl_values_hexadecile, 95)
            hexadecile_medians.append(median_hexadecile)
            hexadecile_lower_errors.append(median_hexadecile - lower_hexadecile)
            hexadecile_upper_errors.append(upper_hexadecile - median_hexadecile)
        else:
            hexadecile_medians.append(np.nan)
            hexadecile_lower_errors.append(0)
            hexadecile_upper_errors.append(0)
    
    # Convert labels to x positions
    x_positions = np.arange(len(n_sims_label))
    
    # Offset for side-by-side plotting
    offset = 0.01  # Adjust as needed
    width = 0.05  # Width of the markers

    # Plotting
    plt.figure(figsize=(12, 8))
    
    # Octiles
    plt.errorbar(
        x_positions - offset,
        octile_medians,
        yerr=[octile_lower_errors, octile_upper_errors],
        fmt='-o',
        label='Octiles',
        capsize=5,
        markersize=8,
        linewidth=2
    )
    
    # Hexadeciles
    plt.errorbar(
        x_positions + offset,
        hexadecile_medians,
        yerr=[hexadecile_lower_errors, hexadecile_upper_errors],
        fmt='-s',
        linestyle='dashed',
        label='Hexadeciles',
        capsize=5,
        markersize=8,
        linewidth=2
    )
    
    plt.xticks(x_positions, n_sims_label, fontsize=24)
    plt.xlabel("Number of Simulations", fontsize=24)
    plt.ylabel(r"KL Divergence", fontsize=24)
    plt.legend(fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=24)
    plt.tight_layout()
    plt.savefig(f"plots/gnk_summaries_hexadeciles_{str(n_obs)}.pdf")
    plt.clf()
# Out:
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/1413037932.py:115: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-s" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.errorbar(
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/1413037932.py:115: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-s" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.errorbar(
# /var/folders/_z/ms2f3nmn0bb7wk4py9_pz7900000gp/T/ipykernel_5161/1413037932.py:115: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-s" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.errorbar(
# ...

# %%
hexadecile_upper_errors

# %%
kl_values_duodecile

# %%
import os
import math
import numpy as np
import matplotlib.pyplot as plt

n_obs_list = [100, 500, 1000, 5000]
simulation_functions = [
    lambda n: n,
    lambda n: int(n * math.log(n)),
    lambda n: int(n ** (3/2)),
    lambda n: n ** 2
]
n_sims_label = [r'$n$', r'$n \log(n)$', r'$n^{3/2}$', r'$n^2$']

num_seeds = 101

base_dir_octiles = "../res/gnk/"
base_dir_duodeciles = "../res/gnk_duodeciles/"

for n_obs in n_obs_list:
    # Lists to store statistics of differences
    diff_medians = []
    diff_lower_errors = []
    diff_upper_errors = []

    for ii, sim_fn in enumerate(simulation_functions):
        n_sims = sim_fn(n_obs)
        kl_differences = []

        for i in range(num_seeds):
            # Octiles
            dir_path_octile = os.path.join(
                base_dir_octiles,
                f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}"
            )
            kl_file_octile = os.path.join(dir_path_octile, "kl.txt")
            kl_value_octile = None
            if os.path.isfile(kl_file_octile):
                with open(kl_file_octile, 'r') as file:
                    try:
                        kl_value = float(file.read().strip())
                        if math.isfinite(kl_value):
                            kl_value_octile = kl_value
                    except ValueError:
                        continue

            # Duodeciles
            dir_path_duodecile = os.path.join(
                base_dir_duodeciles,
                f"npe_n_obs_{n_obs}_n_sims_{n_sims}_seed_{str(i)}"
            )
            kl_file_duodecile = os.path.join(dir_path_duodecile, "kl.txt")
            kl_value_duodecile = None
            if os.path.isfile(kl_file_duodecile):
                with open(kl_file_duodecile, 'r') as file:
                    try:
                        kl_value = float(file.read().strip())
                        if math.isfinite(kl_value):
                            kl_value_duodecile = kl_value
                    except ValueError:
                        continue

            # If both values are available, compute difference
            if kl_value_octile is not None and kl_value_duodecile is not None:
                diff = kl_value_duodecile - kl_value_octile
                kl_differences.append(diff)

        # Calculate statistics of differences
        if kl_differences:
            median_diff = np.median(kl_differences)
            lower_diff = median_diff - np.percentile(kl_differences, 5)
            upper_diff = np.percentile(kl_differences, 95) - median_diff
            diff_medians.append(median_diff)
            diff_lower_errors.append(lower_diff)
            diff_upper_errors.append(upper_diff)
        else:
            diff_medians.append(np.nan)
            diff_lower_errors.append(0)
            diff_upper_errors.append(0)

    # Convert labels to x positions
    x_positions = np.arange(len(n_sims_label))

    # Plotting
    plt.figure(figsize=(12, 8))

    # Plot differences
    plt.errorbar(
        x_positions,
        diff_medians,
        yerr=[diff_lower_errors, diff_upper_errors],
        fmt='-o',
        capsize=5,
        markersize=8,
        linewidth=2
    )

    plt.axhline(0, color='black', linestyle='--', linewidth=1)

    plt.xticks(x_positions, n_sims_label, fontsize=24)
    plt.xlabel("Number of Simulations", fontsize=24)
    plt.ylabel(r"Difference in KL Divergence", fontsize=24)
    plt.title(f"Difference in KL Divergence (Duodecile - Octile) (n_obs = {n_obs})", fontsize=26)
    plt.tick_params(axis='both', which='major', labelsize=24)
    plt.tight_layout()
    plt.savefig(f"plots/gnk_differences_{str(n_obs)}.pdf")
    plt.clf()
